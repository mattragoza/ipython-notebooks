# %%
from __future__ import print_function, division
import sys, os, time
import molgrid

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
sns.set_context('notebook')
sns.set_palette('bright')
from IPython import display
# %matplotlib inline

# %%
import openbabel as ob

old_data_file = '/home/mtr22/cnn/gan/data/lowrmsd.types'
new_data_file = '/home/mtr22/cnn/gan/data/small.types'
data_root = '/home/mtr22/PDBbind/refined-set/'

conv = ob.OBConversion()
oldf = open(old_data_file, 'r')
newf = open(new_data_file, 'w')
for line in oldf:
    target = line.split()[2].split('/')[0]
    lig_file = data_root + target + '/' + target + '_min.sdf'
    mol = ob.OBMol()
    conv.ReadFile(mol, lig_file)
    mol.DeleteHydrogens()
    if mol.NumAtoms() <= 20: # TODO why is this not working?
        newf.write(line)
        print(mol.NumAtoms(), line, end='')
    
oldf.close()
newf.close()
# Out:
# 12 1 6.5229 1alw/1alw_rec.gninatypes 1alw/1alw_ligand_7.gninatypes # 1.60994 -5.22838
# 12 1 6.5229 1alw/1alw_rec.gninatypes 1alw/1alw_ligand_10.gninatypes # 1.0434 -4.85317
# 9 1 4.3010 1amk/1amk_rec.gninatypes 1amk/1amk_ligand_2.gninatypes # 1.4087 -5.71136
# 9 1 4.3010 1amk/1amk_rec.gninatypes 1amk/1amk_min.gninatypes # 0.924963 -5.57349
# 10 1 8.0000 1b57/1b57_rec.gninatypes 1b57/1b57_min.gninatypes # 1.28019 -6.19858
# 20 1 10.5229 1b8n/1b8n_rec.gninatypes 1b8n/1b8n_ligand_1.gninatypes # 1.12898 -9.6595
# 20 1 10.5229 1b8n/1b8n_rec.gninatypes 1b8n/1b8n_min.gninatypes # 0.708213 -9.70241
# 19 1 10.6383 1b8o/1b8o_rec.gninatypes 1b8o/1b8o_ligand_2.gninatypes # 1.27311 -8.81713
# 19 1 10.6383 1b8o/1b8o_rec.gninatypes 1b8o/1b8o_min.gninatypes # 0.712794 -9.64143
# 8 1 8.6990 1bcd/1bcd_rec.gninatypes 1bcd/1bcd_ligand_0.gninatypes # 1.60368 -5.65825
# 8 1 8.6990 1bcd/1bcd_rec.gninatypes 1bcd/1bcd_ligand_1.gninatypes # 0.442486 -5.63452
# 8 1 8.6990 1bcd/1bcd_rec.gninatypes 1bcd/1bcd_ligand_2.gninatypes # 0.438137 -5.63222
# 8 1 8.6990 1bcd/1bcd_rec.gninatypes 1bcd/1bcd_ligand_3.gninatypes # 0.477232 -5.61966
# 8 1 8.6990 1bcd/1bcd_rec.gninatypes 1bcd/1bcd_ligand_4.gninatypes # 1.59293 -5.2261
# 8 1 8.6990 1bcd/1bcd_rec.gninatypes 1bcd/1bcd_ligand_6.gninatypes # 0.713694 -4.96847
# 8 1 8.6990 1bcd/1bcd_rec.gninatypes 1bcd/1bcd_ligand_7.gninatypes # 1.70578 -4.95206
# 8 1 8.6990 1bcd/1bcd_rec.gninatypes 1bcd/1bcd_ligand_8.gninatypes # 1.86112 -4.93031
# 8 1 8.6990 1bcd/1bcd_rec.gninatypes 1bcd/1bcd_ligand_9.gninatypes # 0.903424 -4.90953
# 8 1 8.6990 1bcd/1bcd_rec.gninatypes 1bcd/1bcd_ligand_10.gninatypes # 0.893906 -4.90677
# 8 1 8.6990 1bcd/1bcd_rec.gninatypes 1bcd/1bcd_min.gninatypes # 0.464795 -5.63821
# 16 1 3.2757 1bcu/1bcu_rec.gninatypes 1bcu/1bcu_ligand_0.gninatypes # 0.645585 -7.62018
# 16 1 3.2757 1bcu/1bcu_rec.gninatypes 1bcu/1bcu_ligand_1.gninatypes # 0.669223 -7.60228
# 16 1 3.2757 1bcu/1bcu_rec.gninatypes 1bcu/1bcu_min.gninatypes # 0.124813 -7.07515
# 12 1 3.6778 1c3x/1c3x_rec.gninatypes 1c3x/1c3x_min.gninatypes # 0.552342 -5.80427
# 13 1 6.6778 1c5x/1c5x_rec.gninatypes 1c5x/1c5x_ligand_0.gninatypes # 1.26595 -6.35178
# 13 1 6.6778 1c5x/1c5x_rec.gninatypes 1c5x/1c5x_min.gninatypes # 0.484743 -6.55167
# 12 1 4.2007 1c5y/1c5y_rec.gninatypes 1c5y/1c5y_ligand_0.gninatypes # 0.498476 -6.66865
# 12 1 4.2007 1c5y/1c5y_rec.gninatypes 1c5y/1c5y_ligand_2.gninatypes # 1.58686 -6.39603
# 12 1 4.2007 1c5y/1c5y_rec.gninatypes 1c5y/1c5y_ligand_4.gninatypes # 1.29302 -6.03307
# 12 1 4.2007 1c5y/1c5y_rec.gninatypes 1c5y/1c5y_ligand_11.gninatypes # 1.88016 -5.34097
# 12 1 4.2007 1c5y/1c5y_rec.gninatypes 1c5y/1c5y_min.gninatypes # 0.429305 -6.29173
# 9 1 4.0132 1c5z/1c5z_rec.gninatypes 1c5z/1c5z_ligand_0.gninatypes # 0.444308 -5.99487
# 9 1 4.0132 1c5z/1c5z_rec.gninatypes 1c5z/1c5z_ligand_1.gninatypes # 0.444114 -5.99252
# 9 1 4.0132 1c5z/1c5z_rec.gninatypes 1c5z/1c5z_ligand_2.gninatypes # 0.811128 -5.4025
# 9 1 4.0132 1c5z/1c5z_rec.gninatypes 1c5z/1c5z_ligand_3.gninatypes # 0.822212 -5.38539
# 9 1 4.0132 1c5z/1c5z_rec.gninatypes 1c5z/1c5z_min.gninatypes # 0.417506 -5.20057
# 11 1 6.0000 1ceb/1ceb_rec.gninatypes 1ceb/1ceb_ligand_0.gninatypes # 1.12805 -5.84394
# 11 1 6.0000 1ceb/1ceb_rec.gninatypes 1ceb/1ceb_ligand_1.gninatypes # 1.29277 -5.74122
# 11 1 6.0000 1ceb/1ceb_rec.gninatypes 1ceb/1ceb_ligand_2.gninatypes # 1.3425 -5.32603
# 11 1 6.0000 1ceb/1ceb_rec.gninatypes 1ceb/1ceb_ligand_5.gninatypes # 1.3888 -5.17871
# 11 1 6.0000 1ceb/1ceb_rec.gninatypes 1ceb/1ceb_ligand_9.gninatypes # 1.71432 -4.29624
# 11 1 6.0000 1ceb/1ceb_rec.gninatypes 1ceb/1ceb_min.gninatypes # 0.566665 -5.94128
# 16 1 4.5229 1ctt/1ctt_rec.gninatypes 1ctt/1ctt_ligand_0.gninatypes # 0.529673 -9.79498
# 16 1 4.5229 1ctt/1ctt_rec.gninatypes 1ctt/1ctt_min.gninatypes # 0.589171 -9.8889
# 17 1 11.9208 1ctu/1ctu_rec.gninatypes 1ctu/1ctu_ligand_0.gninatypes # 0.774882 -9.80722
# 17 1 11.9208 1ctu/1ctu_rec.gninatypes 1ctu/1ctu_min.gninatypes # 0.729032 -10.3048
# 16 1 7.5686 1d09/1d09_rec.gninatypes 1d09/1d09_ligand_2.gninatypes # 0.84204 -9.48136
# 16 1 7.5686 1d09/1d09_rec.gninatypes 1d09/1d09_ligand_5.gninatypes # 1.38894 -8.46342
# 16 1 7.5686 1d09/1d09_rec.gninatypes 1d09/1d09_min.gninatypes # 0.441447 -9.36613
# 10 1 6.8239 1drk/1drk_rec.gninatypes 1drk/1drk_ligand_0.gninatypes # 0.178217 -7.6523
# 10 1 6.8239 1drk/1drk_rec.gninatypes 1drk/1drk_min.gninatypes # 0.175695 -7.67487
# 17 1 11.7959 1duv/1duv_rec.gninatypes 1duv/1duv_ligand_0.gninatypes # 1.1588 -8.75494
# 17 1 11.7959 1duv/1duv_rec.gninatypes 1duv/1duv_ligand_9.gninatypes # 1.64254 -7.75694
# 19 1 4.3565 1dy4/1dy4_rec.gninatypes 1dy4/1dy4_ligand_0.gninatypes # 0.714621 -9.22604
# 19 1 4.3565 1dy4/1dy4_rec.gninatypes 1dy4/1dy4_min.gninatypes # 0.39392 -9.33874
# 18 1 4.9208 1e1v/1e1v_rec.gninatypes 1e1v/1e1v_ligand_12.gninatypes # 1.39418 -7.25942
# 18 1 4.9208 1e1v/1e1v_rec.gninatypes 1e1v/1e1v_min.gninatypes # 0.544411 -7.21219
# 18 1 5.8861 1e1x/1e1x_rec.gninatypes 1e1x/1e1x_ligand_8.gninatypes # 1.6288 -7.37031
# 18 1 5.8861 1e1x/1e1x_rec.gninatypes 1e1x/1e1x_ligand_16.gninatypes # 1.19813 -7.0693
# 18 1 5.8861 1e1x/1e1x_rec.gninatypes 1e1x/1e1x_min.gninatypes # 1.01564 -7.2135
# 18 1 4.9431 1e2k/1e2k_rec.gninatypes 1e2k/1e2k_ligand_0.gninatypes # 0.789994 -9.38271
# 18 1 4.9431 1e2k/1e2k_rec.gninatypes 1e2k/1e2k_ligand_2.gninatypes # 1.09451 -7.46468
# 18 1 4.9431 1e2k/1e2k_rec.gninatypes 1e2k/1e2k_min.gninatypes # 0.52775 -9.75424
# 18 1 4.2882 1e2l/1e2l_rec.gninatypes 1e2l/1e2l_ligand_0.gninatypes # 0.855004 -9.40201
# 18 1 4.2882 1e2l/1e2l_rec.gninatypes 1e2l/1e2l_min.gninatypes # 0.789448 -9.62485
# 13 1 3.0969 1ec9/1ec9_rec.gninatypes 1ec9/1ec9_min.gninatypes # 1.16926 -6.94199
# 13 1 3.0000 1ecq/1ecq_rec.gninatypes 1ecq/1ecq_min.gninatypes # 1.00644 -5.25254
# 9 1 5.6990 1egh/1egh_rec.gninatypes 1egh/1egh_ligand_0.gninatypes # 0.663622 -6.52558
# 9 1 5.6990 1egh/1egh_rec.gninatypes 1egh/1egh_ligand_5.gninatypes # 0.966287 -6.18572
# 9 1 5.6990 1egh/1egh_rec.gninatypes 1egh/1egh_ligand_11.gninatypes # 1.63981 -5.4317
# 9 1 5.6990 1egh/1egh_rec.gninatypes 1egh/1egh_min.gninatypes # 0.80439 -7.18473
# 13 1 5.0809 1enu/1enu_rec.gninatypes 1enu/1enu_ligand_0.gninatypes # 0.255033 -8.4073
# 13 1 5.0809 1enu/1enu_rec.gninatypes 1enu/1enu_ligand_6.gninatypes # 1.37887 -7.64544
# 13 1 5.0809 1enu/1enu_rec.gninatypes 1enu/1enu_ligand_8.gninatypes # 1.93681 -7.37207
# 13 1 5.0809 1enu/1enu_rec.gninatypes 1enu/1enu_min.gninatypes # 0.283705 -8.40294
# 14 1 6.6990 1f3e/1f3e_rec.gninatypes 1f3e/1f3e_ligand_0.gninatypes # 0.343401 -8.41975
# 14 1 6.6990 1f3e/1f3e_rec.gninatypes 1f3e/1f3e_ligand_7.gninatypes # 1.97747 -7.41304
# 14 1 6.6990 1f3e/1f3e_rec.gninatypes 1f3e/1f3e_ligand_13.gninatypes # 1.3496 -7.17659
# 14 1 6.6990 1f3e/1f3e_rec.gninatypes 1f3e/1f3e_min.gninatypes # 0.288514 -8.36641
# 20 1 5.5850 1f4x/1f4x_rec.gninatypes 1f4x/1f4x_min.gninatypes # 0.82663 -6.25448
# 20 1 5.3979 1f8b/1f8b_rec.gninatypes 1f8b/1f8b_ligand_7.gninatypes # 1.64764 -6.95002
# 20 1 5.3979 1f8b/1f8b_rec.gninatypes 1f8b/1f8b_ligand_20.gninatypes # 1.27234 -6.64294
# 20 1 5.3979 1f8b/1f8b_rec.gninatypes 1f8b/1f8b_min.gninatypes # 0.54278 -7.04535
# 20 1 7.3979 1f8c/1f8c_rec.gninatypes 1f8c/1f8c_ligand_8.gninatypes # 0.615501 -7.27607
# 20 1 7.3979 1f8c/1f8c_rec.gninatypes 1f8c/1f8c_min.gninatypes # 0.528236 -6.99758
# 20 1 3.3979 1f8d/1f8d_rec.gninatypes 1f8d/1f8d_ligand_8.gninatypes # 0.68551 -7.28736
# 20 1 3.3979 1f8d/1f8d_rec.gninatypes 1f8d/1f8d_min.gninatypes # 0.573704 -7.03308
# 20 1 4.8239 1f8e/1f8e_rec.gninatypes 1f8e/1f8e_ligand_7.gninatypes # 0.667801 -7.42652
# 20 1 4.8239 1f8e/1f8e_rec.gninatypes 1f8e/1f8e_min.gninatypes # 0.513017 -6.92115
# 18 1 5.2366 1fh7/1fh7_rec.gninatypes 1fh7/1fh7_ligand_0.gninatypes # 0.534742 -7.79075
# 18 1 5.2366 1fh7/1fh7_rec.gninatypes 1fh7/1fh7_min.gninatypes # 0.40333 -8.02524
# 17 1 6.8861 1fh8/1fh8_rec.gninatypes 1fh8/1fh8_ligand_1.gninatypes # 0.202937 -7.60184
# 17 1 6.8861 1fh8/1fh8_rec.gninatypes 1fh8/1fh8_ligand_8.gninatypes # 1.94421 -6.3451
# 17 1 6.8861 1fh8/1fh8_rec.gninatypes 1fh8/1fh8_min.gninatypes # 0.290492 -7.88616
# 20 1 6.4318 1fh9/1fh9_rec.gninatypes 1fh9/1fh9_ligand_0.gninatypes # 0.353619 -9.14162
# 20 1 6.4318 1fh9/1fh9_rec.gninatypes 1fh9/1fh9_min.gninatypes # 0.359136 -8.74615
# 13 1 7.6055 1ftm/1ftm_rec.gninatypes 1ftm/1ftm_ligand_0.gninatypes # 1.16663 -7.94333
# 13 1 7.6055 1ftm/1ftm_rec.gninatypes 1ftm/1ftm_ligand_1.gninatypes # 1.83164 -7.54681
# 13 1 7.6055 1ftm/1ftm_rec.gninatypes 1ftm/1ftm_ligand_2.gninatypes # 1.69282 -7.25026
# 13 1 7.6055 1ftm/1ftm_rec.gninatypes 1ftm/1ftm_min.gninatypes # 0.414273 -8.08392
# 19 1 10.5528 1g2o/1g2o_rec.gninatypes 1g2o/1g2o_ligand_2.gninatypes # 1.40121 -9.08402
# 19 1 10.5528 1g2o/1g2o_rec.gninatypes 1g2o/1g2o_min.gninatypes # 1.66014 -8.11204
# 20 1 8.2518 1g4o/1g4o_rec.gninatypes 1g4o/1g4o_ligand_6.gninatypes # 1.63377 -7.33496
# 20 1 8.2518 1g4o/1g4o_rec.gninatypes 1g4o/1g4o_min.gninatypes # 0.967928 -7.06057
# 9 1 5.4815 1g85/1g85_rec.gninatypes 1g85/1g85_ligand_22.gninatypes # 1.84233 -5.0822
# 9 1 5.4815 1g85/1g85_rec.gninatypes 1g85/1g85_min.gninatypes # 1.78669 -4.95577
# 19 1 4.5086 1gi7/1gi7_rec.gninatypes 1gi7/1gi7_ligand_0.gninatypes # 1.19247 -8.74958
# 19 1 4.5086 1gi7/1gi7_rec.gninatypes 1gi7/1gi7_min.gninatypes # 1.30512 -8.12205
# 13 1 3.7235 1grp/1grp_rec.gninatypes 1grp/1grp_ligand_5.gninatypes # 0.872322 -5.96259
# 13 1 3.7235 1grp/1grp_rec.gninatypes 1grp/1grp_ligand_6.gninatypes # 1.4251 -5.91814
# 13 1 3.7235 1grp/1grp_rec.gninatypes 1grp/1grp_ligand_7.gninatypes # 1.94375 -5.87265
# 13 1 3.7235 1grp/1grp_rec.gninatypes 1grp/1grp_ligand_9.gninatypes # 1.4206 -5.83459
# 13 1 3.7235 1grp/1grp_rec.gninatypes 1grp/1grp_min.gninatypes # 0.381912 -5.78522
# 9 1 2.4815 1gyx/1gyx_rec.gninatypes 1gyx/1gyx_ligand_0.gninatypes # 0.478598 -6.17752
# 9 1 2.4815 1gyx/1gyx_rec.gninatypes 1gyx/1gyx_ligand_1.gninatypes # 0.484175 -6.17371
# 9 1 2.4815 1gyx/1gyx_rec.gninatypes 1gyx/1gyx_ligand_6.gninatypes # 1.85774 -5.60201
# 9 1 2.4815 1gyx/1gyx_rec.gninatypes 1gyx/1gyx_ligand_7.gninatypes # 1.80531 -5.58266
# 9 1 2.4815 1gyx/1gyx_rec.gninatypes 1gyx/1gyx_min.gninatypes # 0.238004 -5.92819
# 13 1 3.6383 1gyy/1gyy_rec.gninatypes 1gyy/1gyy_ligand_7.gninatypes # 1.97826 -5.80243
# 13 1 3.6383 1gyy/1gyy_rec.gninatypes 1gyy/1gyy_ligand_9.gninatypes # 0.595892 -5.57786
# 13 1 3.6383 1gyy/1gyy_rec.gninatypes 1gyy/1gyy_ligand_11.gninatypes # 1.66225 -5.19536
# 13 1 3.6383 1gyy/1gyy_rec.gninatypes 1gyy/1gyy_min.gninatypes # 0.559745 -6.21743
# 16 1 5.8239 1hdq/1hdq_rec.gninatypes 1hdq/1hdq_ligand_0.gninatypes # 1.50475 -7.56961
# 16 1 5.8239 1hdq/1hdq_rec.gninatypes 1hdq/1hdq_ligand_3.gninatypes # 1.68825 -7.14004
# 16 1 5.8239 1hdq/1hdq_rec.gninatypes 1hdq/1hdq_ligand_7.gninatypes # 1.87708 -6.87094
# 16 1 5.8239 1hdq/1hdq_rec.gninatypes 1hdq/1hdq_ligand_15.gninatypes # 1.69516 -6.4648
# 16 1 5.8239 1hdq/1hdq_rec.gninatypes 1hdq/1hdq_min.gninatypes # 0.882351 -7.36537
# 14 1 6.2366 1hnn/1hnn_rec.gninatypes 1hnn/1hnn_ligand_0.gninatypes # 0.468491 -8.75244
# 14 1 6.2366 1hnn/1hnn_rec.gninatypes 1hnn/1hnn_ligand_4.gninatypes # 1.97653 -7.52641
# 14 1 6.2366 1hnn/1hnn_rec.gninatypes 1hnn/1hnn_min.gninatypes # 0.305015 -8.28092
# 14 1 6.5528 1hp5/1hp5_rec.gninatypes 1hp5/1hp5_ligand_1.gninatypes # 0.316597 -6.97285
# 14 1 6.5528 1hp5/1hp5_rec.gninatypes 1hp5/1hp5_min.gninatypes # 0.318777 -7.13444
# 11 1 7.1938 1hsl/1hsl_rec.gninatypes 1hsl/1hsl_ligand_2.gninatypes # 0.486541 -6.30643
# 11 1 7.1938 1hsl/1hsl_rec.gninatypes 1hsl/1hsl_ligand_4.gninatypes # 1.14183 -5.82434
# 11 1 7.1938 1hsl/1hsl_rec.gninatypes 1hsl/1hsl_min.gninatypes # 0.396569 -6.38088
# 10 1 6.6198 1ii5/1ii5_rec.gninatypes 1ii5/1ii5_ligand_1.gninatypes # 1.02443 -5.71545
# 10 1 6.6198 1ii5/1ii5_rec.gninatypes 1ii5/1ii5_min.gninatypes # 0.285543 -5.85894
# 10 1 7.4089 1ik4/1ik4_rec.gninatypes 1ik4/1ik4_ligand_0.gninatypes # 0.806983 -7.16599
# 10 1 7.4089 1ik4/1ik4_rec.gninatypes 1ik4/1ik4_min.gninatypes # 0.776654 -7.17128
# 18 1 6.4685 1j01/1j01_rec.gninatypes 1j01/1j01_min.gninatypes # 0.515717 -8.90929
# 9 1 4.4921 1j14/1j14_rec.gninatypes 1j14/1j14_ligand_0.gninatypes # 0.25544 -5.9493
# 9 1 4.4921 1j14/1j14_rec.gninatypes 1j14/1j14_ligand_1.gninatypes # 0.239414 -5.943
# 9 1 4.4921 1j14/1j14_rec.gninatypes 1j14/1j14_min.gninatypes # 0.61702 -4.95219
# 14 1 8.9586 1j37/1j37_rec.gninatypes 1j37/1j37_ligand_13.gninatypes # 1.89429 -5.51144
# 14 1 8.9586 1j37/1j37_rec.gninatypes 1j37/1j37_min.gninatypes # 0.6536 -6.16489
# 14 1 5.5686 1jak/1jak_rec.gninatypes 1jak/1jak_ligand_0.gninatypes # 1.95374 -7.1156
# 14 1 5.5686 1jak/1jak_rec.gninatypes 1jak/1jak_min.gninatypes # 0.458914 -6.81645
# 20 1 9.0000 1k27/1k27_rec.gninatypes 1k27/1k27_ligand_0.gninatypes # 0.823371 -9.17924
# 20 1 9.0000 1k27/1k27_rec.gninatypes 1k27/1k27_min.gninatypes # 0.558469 -9.57692
# 20 1 5.8539 1k4g/1k4g_rec.gninatypes 1k4g/1k4g_ligand_0.gninatypes # 1.45545 -9.25262
# 20 1 5.8539 1k4g/1k4g_rec.gninatypes 1k4g/1k4g_min.gninatypes # 1.30627 -9.01135
# 18 1 5.1135 1k4h/1k4h_rec.gninatypes 1k4h/1k4h_ligand_0.gninatypes # 0.907406 -8.3421
# 18 1 5.1135 1k4h/1k4h_rec.gninatypes 1k4h/1k4h_ligand_2.gninatypes # 1.94915 -7.58553
# 18 1 5.1135 1k4h/1k4h_rec.gninatypes 1k4h/1k4h_ligand_5.gninatypes # 1.4247 -7.41223
# 18 1 5.1135 1k4h/1k4h_rec.gninatypes 1k4h/1k4h_ligand_6.gninatypes # 1.9296 -6.98336
# 18 1 5.1135 1k4h/1k4h_rec.gninatypes 1k4h/1k4h_min.gninatypes # 0.793478 -8.22443
# 9 1 7.2218 1lan/1lan_rec.gninatypes 1lan/1lan_ligand_1.gninatypes # 1.68281 -4.76044
# 9 1 7.2218 1lan/1lan_rec.gninatypes 1lan/1lan_ligand_2.gninatypes # 1.97578 -4.68918
# 9 1 7.2218 1lan/1lan_rec.gninatypes 1lan/1lan_ligand_3.gninatypes # 1.94948 -4.66277
# 9 1 7.2218 1lan/1lan_rec.gninatypes 1lan/1lan_ligand_7.gninatypes # 1.26771 -4.50278
# 9 1 7.2218 1lan/1lan_rec.gninatypes 1lan/1lan_min.gninatypes # 0.573346 -3.94408
# 10 1 6.6383 1lcp/1lcp_rec.gninatypes 1lcp/1lcp_ligand_0.gninatypes # 0.587912 -5.57976
# 10 1 6.6383 1lcp/1lcp_rec.gninatypes 1lcp/1lcp_ligand_1.gninatypes # 1.90254 -5.48917
# 10 1 6.6383 1lcp/1lcp_rec.gninatypes 1lcp/1lcp_ligand_3.gninatypes # 0.98599 -5.37922
# 10 1 6.6383 1lcp/1lcp_rec.gninatypes 1lcp/1lcp_ligand_8.gninatypes # 1.88861 -5.15947
# 10 1 6.6383 1lcp/1lcp_rec.gninatypes 1lcp/1lcp_ligand_16.gninatypes # 1.93944 -4.88238
# 10 1 6.6383 1lcp/1lcp_rec.gninatypes 1lcp/1lcp_min.gninatypes # 0.36291 -5.30217
# 20 1 5.3188 1lvu/1lvu_rec.gninatypes 1lvu/1lvu_ligand_0.gninatypes # 0.725966 -8.2263
# 20 1 5.3188 1lvu/1lvu_rec.gninatypes 1lvu/1lvu_min.gninatypes # 0.485809 -8.52982
# 9 1 4.5376 1lyx/1lyx_rec.gninatypes 1lyx/1lyx_ligand_3.gninatypes # 0.968648 -5.61431
# 9 1 4.5376 1lyx/1lyx_rec.gninatypes 1lyx/1lyx_ligand_6.gninatypes # 1.34888 -5.32423
# 9 1 4.5376 1lyx/1lyx_rec.gninatypes 1lyx/1lyx_min.gninatypes # 0.682232 -5.07323
# 10 1 4.6576 1m1b/1m1b_rec.gninatypes 1m1b/1m1b_ligand_12.gninatypes # 1.70761 -6.66788
# 10 1 4.6576 1m1b/1m1b_rec.gninatypes 1m1b/1m1b_ligand_13.gninatypes # 1.96028 -6.514
# 10 1 4.6576 1m1b/1m1b_rec.gninatypes 1m1b/1m1b_min.gninatypes # 1.45454 -9.24465
# 20 1 6.0969 1m2q/1m2q_rec.gninatypes 1m2q/1m2q_ligand_5.gninatypes # 0.247887 -9.26394
# 20 1 6.0969 1m2q/1m2q_rec.gninatypes 1m2q/1m2q_ligand_6.gninatypes # 1.27913 -8.79962
# 20 1 6.0969 1m2q/1m2q_rec.gninatypes 1m2q/1m2q_ligand_8.gninatypes # 1.52667 -8.17536
# 20 1 6.0969 1m2q/1m2q_rec.gninatypes 1m2q/1m2q_min.gninatypes # 0.207332 -10.0381
# 20 1 6.4559 1m2r/1m2r_rec.gninatypes 1m2r/1m2r_ligand_2.gninatypes # 1.0262 -9.06288
# 20 1 6.4559 1m2r/1m2r_rec.gninatypes 1m2r/1m2r_min.gninatypes # 0.438906 -10.7214
# 13 1 4.2676 1m5w/1m5w_rec.gninatypes 1m5w/1m5w_ligand_5.gninatypes # 1.90879 -7.6444
# 13 1 4.2676 1m5w/1m5w_rec.gninatypes 1m5w/1m5w_ligand_8.gninatypes # 1.90154 -7.53678
# 13 1 4.2676 1m5w/1m5w_rec.gninatypes 1m5w/1m5w_ligand_9.gninatypes # 1.72497 -7.50636
# 13 1 4.2676 1m5w/1m5w_rec.gninatypes 1m5w/1m5w_ligand_10.gninatypes # 1.8696 -7.45347
# 13 1 4.2676 1m5w/1m5w_rec.gninatypes 1m5w/1m5w_ligand_13.gninatypes # 1.53268 -7.22154
# 13 1 4.2676 1m5w/1m5w_rec.gninatypes 1m5w/1m5w_ligand_16.gninatypes # 1.57977 -6.98971
# 13 1 4.2676 1m5w/1m5w_rec.gninatypes 1m5w/1m5w_min.gninatypes # 1.42383 -7.36099
# 19 1 8.8861 1n3i/1n3i_rec.gninatypes 1n3i/1n3i_ligand_2.gninatypes # 0.674955 -8.68562
# 19 1 8.8861 1n3i/1n3i_rec.gninatypes 1n3i/1n3i_min.gninatypes # 0.642113 -8.84495
# 20 1 6.1249 1nc1/1nc1_rec.gninatypes 1nc1/1nc1_ligand_0.gninatypes # 0.690836 -8.74405
# 20 1 6.1249 1nc1/1nc1_rec.gninatypes 1nc1/1nc1_min.gninatypes # 0.798043 -8.66015
# 20 1 5.5528 1njc/1njc_rec.gninatypes 1njc/1njc_min.gninatypes # 1.39762 -6.97798
# 10 1 4.0000 1nu3/1nu3_rec.gninatypes 1nu3/1nu3_ligand_11.gninatypes # 1.81964 -5.04246
# 10 1 4.0000 1nu3/1nu3_rec.gninatypes 1nu3/1nu3_min.gninatypes # 0.941458 -4.62174
# 19 1 7.6990 1oau/1oau_rec.gninatypes 1oau/1oau_ligand_0.gninatypes # 0.891255 -7.71497
# 19 1 7.6990 1oau/1oau_rec.gninatypes 1oau/1oau_ligand_1.gninatypes # 1.78863 -7.27215
# 19 1 7.6990 1oau/1oau_rec.gninatypes 1oau/1oau_ligand_15.gninatypes # 1.96457 -6.235
# 19 1 7.6990 1oau/1oau_rec.gninatypes 1oau/1oau_min.gninatypes # 0.800474 -7.69533
# 7 1 2.4437 1oba/1oba_rec.gninatypes 1oba/1oba_ligand_23.gninatypes # 1.32156 -2.58483
# 7 1 2.4437 1oba/1oba_rec.gninatypes 1oba/1oba_min.gninatypes # 0.875317 -2.77409
# 19 1 4.2076 1odi/1odi_rec.gninatypes 1odi/1odi_ligand_3.gninatypes # 0.573234 -7.7422
# 19 1 4.2076 1odi/1odi_rec.gninatypes 1odi/1odi_min.gninatypes # 0.856183 -7.63157
# 20 1 4.0969 1odj/1odj_rec.gninatypes 1odj/1odj_ligand_4.gninatypes # 0.981295 -8.4048
# 20 1 4.0969 1odj/1odj_rec.gninatypes 1odj/1odj_min.gninatypes # 0.987467 -8.69546
# 20 1 5.5229 1oe8/1oe8_rec.gninatypes 1oe8/1oe8_min.gninatypes # 1.21759 -5.13954
# 20 1 6.0915 1ogx/1ogx_rec.gninatypes 1ogx/1ogx_ligand_0.gninatypes # 1.06128 -9.05673
# 20 1 6.0915 1ogx/1ogx_rec.gninatypes 1ogx/1ogx_ligand_2.gninatypes # 1.84077 -8.47294
# 20 1 6.0915 1ogx/1ogx_rec.gninatypes 1ogx/1ogx_min.gninatypes # 1.02247 -9.03404
# 17 1 6.0315 1okl/1okl_rec.gninatypes 1okl/1okl_ligand_1.gninatypes # 0.384946 -6.92819
# 17 1 6.0315 1okl/1okl_rec.gninatypes 1okl/1okl_min.gninatypes # 0.356332 -7.01223
# 9 1 4.7852 1oss/1oss_rec.gninatypes 1oss/1oss_ligand_0.gninatypes # 0.580636 -5.67592
# 9 1 4.7852 1oss/1oss_rec.gninatypes 1oss/1oss_ligand_1.gninatypes # 0.579808 -5.65705
# 9 1 4.7852 1oss/1oss_rec.gninatypes 1oss/1oss_ligand_2.gninatypes # 1.56409 -5.58044
# 9 1 4.7852 1oss/1oss_rec.gninatypes 1oss/1oss_ligand_13.gninatypes # 0.75208 -4.97946
# 9 1 4.7852 1oss/1oss_rec.gninatypes 1oss/1oss_min.gninatypes # 0.304449 -5.70503
# 16 1 7.0000 1oth/1oth_rec.gninatypes 1oth/1oth_ligand_0.gninatypes # 0.295796 -8.28523
# 16 1 7.0000 1oth/1oth_rec.gninatypes 1oth/1oth_ligand_1.gninatypes # 1.33466 -8.18171
# 16 1 7.0000 1oth/1oth_rec.gninatypes 1oth/1oth_ligand_2.gninatypes # 1.59919 -8.0615
# 16 1 7.0000 1oth/1oth_rec.gninatypes 1oth/1oth_min.gninatypes # 0.360155 -8.52335
# 13 1 5.1938 1oxr/1oxr_rec.gninatypes 1oxr/1oxr_ligand_11.gninatypes # 1.93025 -5.7551
# 13 1 5.1938 1oxr/1oxr_rec.gninatypes 1oxr/1oxr_ligand_21.gninatypes # 1.02732 -5.05566
# 19 1 4.3979 1p57/1p57_rec.gninatypes 1p57/1p57_ligand_0.gninatypes # 0.629821 -8.49692
# 19 1 4.3979 1p57/1p57_rec.gninatypes 1p57/1p57_ligand_1.gninatypes # 1.76983 -8.31988
# 19 1 4.3979 1p57/1p57_rec.gninatypes 1p57/1p57_min.gninatypes # 0.697315 -8.03903
# 18 1 4.7570 1q8t/1q8t_rec.gninatypes 1q8t/1q8t_ligand_1.gninatypes # 1.43273 -7.98375
# 18 1 4.7570 1q8t/1q8t_rec.gninatypes 1q8t/1q8t_ligand_2.gninatypes # 1.97278 -7.9007
# 18 1 4.7570 1q8t/1q8t_rec.gninatypes 1q8t/1q8t_ligand_3.gninatypes # 1.31363 -7.89522
# 18 1 4.7570 1q8t/1q8t_rec.gninatypes 1q8t/1q8t_ligand_4.gninatypes # 1.72715 -7.79867
# 18 1 4.7570 1q8t/1q8t_rec.gninatypes 1q8t/1q8t_ligand_11.gninatypes # 1.55543 -7.32299
# 18 1 4.7570 1q8t/1q8t_rec.gninatypes 1q8t/1q8t_min.gninatypes # 0.688366 -7.88313
# 20 1 4.0458 1r4w/1r4w_rec.gninatypes 1r4w/1r4w_min.gninatypes # 0.767476 -6.50549
# 8 1 5.3979 1r9l/1r9l_rec.gninatypes 1r9l/1r9l_ligand_0.gninatypes # 0.324933 -4.51345
# 8 1 5.3979 1r9l/1r9l_rec.gninatypes 1r9l/1r9l_min.gninatypes # 0.346626 -4.62278
# 20 1 6.4559 1ro6/1ro6_rec.gninatypes 1ro6/1ro6_ligand_0.gninatypes # 0.651054 -8.33237
# 20 1 6.4559 1ro6/1ro6_rec.gninatypes 1ro6/1ro6_ligand_1.gninatypes # 1.35316 -8.28005
# 20 1 6.4559 1ro6/1ro6_rec.gninatypes 1ro6/1ro6_min.gninatypes # 0.601098 -8.44189
# 6 1 2.7471 1rql/1rql_rec.gninatypes 1rql/1rql_min.gninatypes # 0.50567 -5.67294
# 19 1 10.2518 1rr6/1rr6_rec.gninatypes 1rr6/1rr6_ligand_1.gninatypes # 0.830252 -8.62037
# 19 1 10.2518 1rr6/1rr6_rec.gninatypes 1rr6/1rr6_min.gninatypes # 0.889561 -8.48956
# 13 1 5.1549 1s38/1s38_rec.gninatypes 1s38/1s38_ligand_0.gninatypes # 0.203823 -8.28237
# 13 1 5.1549 1s38/1s38_rec.gninatypes 1s38/1s38_min.gninatypes # 0.221668 -8.38379
# 12 1 7.6990 1s39/1s39_rec.gninatypes 1s39/1s39_ligand_0.gninatypes # 0.306166 -8.21919
# 12 1 7.6990 1s39/1s39_rec.gninatypes 1s39/1s39_min.gninatypes # 0.291761 -8.21766
# 8 1 7.2218 1sw2/1sw2_rec.gninatypes 1sw2/1sw2_ligand_0.gninatypes # 0.888657 -5.0898
# 8 1 7.2218 1sw2/1sw2_rec.gninatypes 1sw2/1sw2_ligand_1.gninatypes # 0.94678 -5.04957
# 8 1 7.2218 1sw2/1sw2_rec.gninatypes 1sw2/1sw2_ligand_3.gninatypes # 1.6713 -4.21304
# 8 1 7.2218 1sw2/1sw2_rec.gninatypes 1sw2/1sw2_min.gninatypes # 0.273358 -5.0646
# 16 1 7.3575 1swg/1swg_rec.gninatypes 1swg/1swg_ligand_3.gninatypes # 1.08086 -6.35153
# 16 1 7.3575 1swg/1swg_rec.gninatypes 1swg/1swg_min.gninatypes # 0.813289 -7.05451
# 17 1 6.4056 1syh/1syh_rec.gninatypes 1syh/1syh_min.gninatypes # 0.16397 -9.55163
# 17 1 5.4449 1syi/1syi_rec.gninatypes 1syi/1syi_ligand_0.gninatypes # 0.252323 -9.28515
# 17 1 5.4449 1syi/1syi_rec.gninatypes 1syi/1syi_min.gninatypes # 0.144857 -9.59363
# 20 1 4.3665 1td7/1td7_rec.gninatypes 1td7/1td7_ligand_20.gninatypes # 1.89392 -6.73738
# 20 1 4.3665 1td7/1td7_rec.gninatypes 1td7/1td7_min.gninatypes # 0.66647 -6.66065
# 13 1 4.0506 1tuf/1tuf_rec.gninatypes 1tuf/1tuf_min.gninatypes # 1.62532 -4.18397
# 12 1 6.1549 1u0g/1u0g_rec.gninatypes 1u0g/1u0g_ligand_0.gninatypes # 0.69314 -7.19139
# 12 1 6.1549 1u0g/1u0g_rec.gninatypes 1u0g/1u0g_ligand_1.gninatypes # 1.99199 -6.92964
# 12 1 6.1549 1u0g/1u0g_rec.gninatypes 1u0g/1u0g_ligand_13.gninatypes # 1.67553 -6.53168
# 12 1 6.1549 1u0g/1u0g_rec.gninatypes 1u0g/1u0g_ligand_21.gninatypes # 1.86956 -6.08302
# 12 1 6.1549 1u0g/1u0g_rec.gninatypes 1u0g/1u0g_min.gninatypes # 0.590495 -7.06937
# 8 1 3.8416 1utj/1utj_rec.gninatypes 1utj/1utj_ligand_0.gninatypes # 0.411351 -4.95803
# 8 1 3.8416 1utj/1utj_rec.gninatypes 1utj/1utj_ligand_1.gninatypes # 0.410702 -4.94831
# 8 1 3.8416 1utj/1utj_rec.gninatypes 1utj/1utj_min.gninatypes # 0.218147 -4.81546
# 10 1 2.4672 1utl/1utl_rec.gninatypes 1utl/1utl_ligand_5.gninatypes # 1.36965 -4.80467
# 10 1 2.4672 1utl/1utl_rec.gninatypes 1utl/1utl_ligand_6.gninatypes # 1.4091 -4.79485
# 10 1 2.4672 1utl/1utl_rec.gninatypes 1utl/1utl_ligand_8.gninatypes # 1.89056 -4.66227
# 10 1 2.4672 1utl/1utl_rec.gninatypes 1utl/1utl_ligand_18.gninatypes # 0.897343 -4.27198
# 10 1 2.4672 1utl/1utl_rec.gninatypes 1utl/1utl_min.gninatypes # 0.662441 -4.29081
# 9 1 3.0123 1utm/1utm_rec.gninatypes 1utm/1utm_ligand_3.gninatypes # 0.748803 -4.68252
# 9 1 3.0123 1utm/1utm_rec.gninatypes 1utm/1utm_ligand_4.gninatypes # 0.723588 -4.65216
# 9 1 3.0123 1utm/1utm_rec.gninatypes 1utm/1utm_ligand_8.gninatypes # 1.15901 -4.24435
# 9 1 3.0123 1utm/1utm_rec.gninatypes 1utm/1utm_min.gninatypes # 0.459738 -4.43691
# 10 1 5.1206 1uv6/1uv6_rec.gninatypes 1uv6/1uv6_ligand_0.gninatypes # 0.970654 -4.6651
# 10 1 5.1206 1uv6/1uv6_rec.gninatypes 1uv6/1uv6_ligand_1.gninatypes # 0.967886 -4.61614
# 10 1 5.1206 1uv6/1uv6_rec.gninatypes 1uv6/1uv6_ligand_8.gninatypes # 0.749978 -4.27373
# 10 1 5.1206 1uv6/1uv6_rec.gninatypes 1uv6/1uv6_min.gninatypes # 0.415459 -4.43175
# 9 1 3.3696 1v2u/1v2u_rec.gninatypes 1v2u/1v2u_ligand_0.gninatypes # 0.333063 -6.01075
# 9 1 3.3696 1v2u/1v2u_rec.gninatypes 1v2u/1v2u_ligand_1.gninatypes # 0.347621 -5.99435
# 9 1 3.3696 1v2u/1v2u_rec.gninatypes 1v2u/1v2u_ligand_2.gninatypes # 0.38867 -5.46951
# 9 1 3.3696 1v2u/1v2u_rec.gninatypes 1v2u/1v2u_ligand_5.gninatypes # 1.50458 -5.15405
# 9 1 3.3696 1v2u/1v2u_rec.gninatypes 1v2u/1v2u_ligand_6.gninatypes # 1.79831 -5.0339
# 9 1 3.3696 1v2u/1v2u_rec.gninatypes 1v2u/1v2u_ligand_11.gninatypes # 1.5268 -4.9426
# 9 1 3.3696 1v2u/1v2u_rec.gninatypes 1v2u/1v2u_min.gninatypes # 0.338714 -6.04908
# 13 1 3.0000 1ws4/1ws4_rec.gninatypes 1ws4/1ws4_ligand_3.gninatypes # 0.807057 -5.47386
# 13 1 3.0000 1ws4/1ws4_rec.gninatypes 1ws4/1ws4_ligand_19.gninatypes # 0.968464 -4.88406
# 13 1 3.0000 1ws4/1ws4_rec.gninatypes 1ws4/1ws4_min.gninatypes # 0.275869 -5.6256
# 15 1 6.1791 1xhy/1xhy_rec.gninatypes 1xhy/1xhy_ligand_3.gninatypes # 1.65871 -6.80476
# 15 1 6.1791 1xhy/1xhy_rec.gninatypes 1xhy/1xhy_min.gninatypes # 0.798126 -8.36645
# 7 1 6.8539 1xt8/1xt8_rec.gninatypes 1xt8/1xt8_min.gninatypes # 0.318675 -5.35221
# 8 1 3.0804 1y1z/1y1z_rec.gninatypes 1y1z/1y1z_ligand_0.gninatypes # 0.152469 -5.90501
# 8 1 3.0804 1y1z/1y1z_rec.gninatypes 1y1z/1y1z_ligand_2.gninatypes # 1.83761 -4.67697
# 8 1 3.0804 1y1z/1y1z_rec.gninatypes 1y1z/1y1z_min.gninatypes # 0.178054 -6.0071
# 20 1 11.6990 1y6q/1y6q_rec.gninatypes 1y6q/1y6q_ligand_0.gninatypes # 0.588486 -9.02365
# 20 1 11.6990 1y6q/1y6q_rec.gninatypes 1y6q/1y6q_ligand_1.gninatypes # 1.92368 -7.51085
# 20 1 11.6990 1y6q/1y6q_rec.gninatypes 1y6q/1y6q_min.gninatypes # 0.670809 -8.46271
# 20 1 10.1135 1y6r/1y6r_rec.gninatypes 1y6r/1y6r_ligand_0.gninatypes # 0.808189 -9.1646
# 20 1 10.1135 1y6r/1y6r_rec.gninatypes 1y6r/1y6r_min.gninatypes # 0.811686 -8.78653
# 13 1 6.5528 1yda/1yda_rec.gninatypes 1yda/1yda_ligand_0.gninatypes # 1.06741 -6.91966
# 13 1 6.5528 1yda/1yda_rec.gninatypes 1yda/1yda_ligand_5.gninatypes # 1.56237 -6.12244
# 13 1 6.5528 1yda/1yda_rec.gninatypes 1yda/1yda_ligand_9.gninatypes # 1.3382 -5.80419
# 13 1 6.5528 1yda/1yda_rec.gninatypes 1yda/1yda_min.gninatypes # 1.03548 -6.32119
# 13 1 8.2366 1ydb/1ydb_rec.gninatypes 1ydb/1ydb_ligand_0.gninatypes # 0.976835 -6.54924
# 13 1 8.2366 1ydb/1ydb_rec.gninatypes 1ydb/1ydb_min.gninatypes # 0.971966 -6.59345
# 13 1 7.0655 1ydd/1ydd_rec.gninatypes 1ydd/1ydd_ligand_15.gninatypes # 1.94138 -5.4527
# 13 1 7.0655 1ydd/1ydd_rec.gninatypes 1ydd/1ydd_min.gninatypes # 0.378852 -6.13265
# 17 1 8.0458 2b9a/2b9a_rec.gninatypes 2b9a/2b9a_ligand_0.gninatypes # 1.94347 -7.80803
# 17 1 8.0458 2b9a/2b9a_rec.gninatypes 2b9a/2b9a_ligand_2.gninatypes # 1.94518 -7.79849
# 17 1 8.0458 2b9a/2b9a_rec.gninatypes 2b9a/2b9a_min.gninatypes # 1.97676 -7.60067
# 14 1 4.2441 2bes/2bes_rec.gninatypes 2bes/2bes_ligand_0.gninatypes # 1.7429 -8.19301
# 14 1 4.2441 2bes/2bes_rec.gninatypes 2bes/2bes_ligand_1.gninatypes # 1.38334 -8.05895
# 14 1 4.2441 2bes/2bes_rec.gninatypes 2bes/2bes_ligand_23.gninatypes # 1.84198 -6.35437
# 14 1 4.2441 2bes/2bes_rec.gninatypes 2bes/2bes_min.gninatypes # 0.550075 -7.31632
# 11 1 5.7696 2boj/2boj_rec.gninatypes 2boj/2boj_ligand_1.gninatypes # 1.7448 -5.43329
# 11 1 5.7696 2boj/2boj_rec.gninatypes 2boj/2boj_ligand_6.gninatypes # 1.34624 -4.91187
# 11 1 5.7696 2boj/2boj_rec.gninatypes 2boj/2boj_min.gninatypes # 0.480601 -5.23624
# 18 1 5.0665 2c3l/2c3l_rec.gninatypes 2c3l/2c3l_ligand_2.gninatypes # 0.63061 -7.88412
# 18 1 5.0665 2c3l/2c3l_rec.gninatypes 2c3l/2c3l_min.gninatypes # 0.932875 -7.52016
# 20 1 4.6576 2ca8/2ca8_rec.gninatypes 2ca8/2ca8_min.gninatypes # 1.09041 -5.73381
# 13 1 5.6778 2cbu/2cbu_rec.gninatypes 2cbu/2cbu_ligand_1.gninatypes # 1.93119 -7.37166
# 13 1 5.6778 2cbu/2cbu_rec.gninatypes 2cbu/2cbu_min.gninatypes # 0.499401 -8.12022
# 12 1 5.4815 2cbv/2cbv_rec.gninatypes 2cbv/2cbv_ligand_0.gninatypes # 0.456767 -7.77136
# 12 1 5.4815 2cbv/2cbv_rec.gninatypes 2cbv/2cbv_min.gninatypes # 0.452633 -7.86081
# 18 1 8.0052 2cc7/2cc7_rec.gninatypes 2cc7/2cc7_ligand_10.gninatypes # 0.418977 -8.25488
# 18 1 8.0052 2cc7/2cc7_rec.gninatypes 2cc7/2cc7_min.gninatypes # 0.335982 -8.27579
# 19 1 7.7552 2ccc/2ccc_rec.gninatypes 2ccc/2ccc_ligand_8.gninatypes # 0.444017 -8.26221
# 19 1 7.7552 2ccc/2ccc_rec.gninatypes 2ccc/2ccc_min.gninatypes # 0.558666 -8.40309
# 20 1 4.6990 2cex/2cex_rec.gninatypes 2cex/2cex_min.gninatypes # 0.487557 -6.84673
# 12 1 3.8861 2ctc/2ctc_rec.gninatypes 2ctc/2ctc_ligand_0.gninatypes # 0.532996 -6.86436
# 12 1 3.8861 2ctc/2ctc_rec.gninatypes 2ctc/2ctc_ligand_1.gninatypes # 0.494101 -6.82666
# 12 1 3.8861 2ctc/2ctc_rec.gninatypes 2ctc/2ctc_ligand_4.gninatypes # 1.57067 -6.60485
# 12 1 3.8861 2ctc/2ctc_rec.gninatypes 2ctc/2ctc_ligand_5.gninatypes # 1.68546 -6.57957
# 12 1 3.8861 2ctc/2ctc_rec.gninatypes 2ctc/2ctc_ligand_9.gninatypes # 1.40411 -6.33355
# 12 1 3.8861 2ctc/2ctc_rec.gninatypes 2ctc/2ctc_min.gninatypes # 0.483839 -6.73921
# 17 1 8.2596 2e2r/2e2r_rec.gninatypes 2e2r/2e2r_ligand_0.gninatypes # 0.487972 -10.4323
# 17 1 8.2596 2e2r/2e2r_rec.gninatypes 2e2r/2e2r_ligand_1.gninatypes # 0.500219 -10.4281
# 17 1 8.2596 2e2r/2e2r_rec.gninatypes 2e2r/2e2r_ligand_2.gninatypes # 0.461653 -10.4031
# 17 1 8.2596 2e2r/2e2r_rec.gninatypes 2e2r/2e2r_ligand_3.gninatypes # 0.495731 -10.3849
# 17 1 8.2596 2e2r/2e2r_rec.gninatypes 2e2r/2e2r_min.gninatypes # 0.375035 -10.221
# 14 1 7.2218 2epn/2epn_rec.gninatypes 2epn/2epn_ligand_0.gninatypes # 0.163857 -6.83009
# 14 1 7.2218 2epn/2epn_rec.gninatypes 2epn/2epn_min.gninatypes # 0.341151 -7.06576
# 15 1 4.1079 2exm/2exm_rec.gninatypes 2exm/2exm_min.gninatypes # 0.551064 -5.61459
# 19 1 6.7100 2f94/2f94_rec.gninatypes 2f94/2f94_ligand_2.gninatypes # 1.27247 -8.08585
# 19 1 6.7100 2f94/2f94_rec.gninatypes 2f94/2f94_ligand_3.gninatypes # 1.82024 -8.02015
# 19 1 6.7100 2f94/2f94_rec.gninatypes 2f94/2f94_ligand_15.gninatypes # 1.95915 -7.5014
# 19 1 6.7100 2f94/2f94_rec.gninatypes 2f94/2f94_ligand_22.gninatypes # 1.81498 -7.14083
# 19 1 6.7100 2f94/2f94_rec.gninatypes 2f94/2f94_min.gninatypes # 1.33745 -7.53043
# 16 1 7.0660 2f9k/2f9k_rec.gninatypes 2f9k/2f9k_ligand_9.gninatypes # 1.82373 -7.54124
# 16 1 7.0660 2f9k/2f9k_rec.gninatypes 2f9k/2f9k_ligand_10.gninatypes # 1.68018 -7.52516
# 16 1 7.0660 2f9k/2f9k_rec.gninatypes 2f9k/2f9k_min.gninatypes # 1.13503 -7.37457
# 10 1 3.9586 2fpz/2fpz_rec.gninatypes 2fpz/2fpz_ligand_0.gninatypes # 1.21216 -6.01494
# 10 1 3.9586 2fpz/2fpz_rec.gninatypes 2fpz/2fpz_min.gninatypes # 0.359835 -5.79066
# 9 1 6.3979 2g9q/2g9q_rec.gninatypes 2g9q/2g9q_ligand_4.gninatypes # 0.871398 -5.66699
# 9 1 6.3979 2g9q/2g9q_rec.gninatypes 2g9q/2g9q_min.gninatypes # 0.817562 -5.02915
# 19 1 4.8239 2gl0/2gl0_rec.gninatypes 2gl0/2gl0_ligand_0.gninatypes # 0.689152 -8.86889
# 19 1 4.8239 2gl0/2gl0_rec.gninatypes 2gl0/2gl0_min.gninatypes # 0.849417 -8.38778
# 15 1 3.9031 2gvv/2gvv_rec.gninatypes 2gvv/2gvv_ligand_0.gninatypes # 1.36105 -7.32705
# 15 1 3.9031 2gvv/2gvv_rec.gninatypes 2gvv/2gvv_ligand_1.gninatypes # 1.27926 -7.22338
# 15 1 3.9031 2gvv/2gvv_rec.gninatypes 2gvv/2gvv_ligand_2.gninatypes # 1.26844 -7.20937
# 15 1 3.9031 2gvv/2gvv_rec.gninatypes 2gvv/2gvv_ligand_3.gninatypes # 1.38559 -6.92712
# 15 1 3.9031 2gvv/2gvv_rec.gninatypes 2gvv/2gvv_ligand_4.gninatypes # 1.17341 -6.697
# 15 1 3.9031 2gvv/2gvv_rec.gninatypes 2gvv/2gvv_ligand_5.gninatypes # 1.73089 -6.33908
# 15 1 3.9031 2gvv/2gvv_rec.gninatypes 2gvv/2gvv_ligand_7.gninatypes # 1.68402 -6.17174
# 15 1 3.9031 2gvv/2gvv_rec.gninatypes 2gvv/2gvv_ligand_14.gninatypes # 1.83413 -5.69526
# 15 1 3.9031 2gvv/2gvv_rec.gninatypes 2gvv/2gvv_min.gninatypes # 1.11041 -6.85107
# 14 1 5.0969 2h5a/2h5a_rec.gninatypes 2h5a/2h5a_ligand_3.gninatypes # 1.93146 -6.90516
# 14 1 5.0969 2h5a/2h5a_rec.gninatypes 2h5a/2h5a_ligand_14.gninatypes # 1.99742 -6.33152
# 14 1 5.0969 2h5a/2h5a_rec.gninatypes 2h5a/2h5a_min.gninatypes # 0.547976 -6.33711
# 20 1 4.6576 2ha2/2ha2_rec.gninatypes 2ha2/2ha2_ligand_8.gninatypes # 1.91581 -6.18069
# 20 1 4.6576 2ha2/2ha2_rec.gninatypes 2ha2/2ha2_ligand_17.gninatypes # 1.51986 -6.10314
# 20 1 4.6576 2ha2/2ha2_rec.gninatypes 2ha2/2ha2_ligand_23.gninatypes # 1.84847 -5.95005
# 20 1 4.6576 2ha2/2ha2_rec.gninatypes 2ha2/2ha2_min.gninatypes # 1.96462 -5.50737
# 7 1 3.0315 2ha3/2ha3_rec.gninatypes 2ha3/2ha3_ligand_4.gninatypes # 1.10851 -3.66118
# 7 1 3.0315 2ha3/2ha3_rec.gninatypes 2ha3/2ha3_ligand_20.gninatypes # 1.99345 -3.34824
# 7 1 3.0315 2ha3/2ha3_rec.gninatypes 2ha3/2ha3_min.gninatypes # 0.692421 -3.59257
# 9 1 4.9208 2haw/2haw_rec.gninatypes 2haw/2haw_ligand_1.gninatypes # 1.84522 -7.01278
# 9 1 4.9208 2haw/2haw_rec.gninatypes 2haw/2haw_ligand_2.gninatypes # 0.866621 -7.00032
# 9 1 4.9208 2haw/2haw_rec.gninatypes 2haw/2haw_ligand_4.gninatypes # 1.83019 -6.93913
# 9 1 4.9208 2haw/2haw_rec.gninatypes 2haw/2haw_min.gninatypes # 1.36084 -6.87714
# 10 1 4.3947 2hjb/2hjb_rec.gninatypes 2hjb/2hjb_ligand_0.gninatypes # 1.32087 -6.32232
# 10 1 4.3947 2hjb/2hjb_rec.gninatypes 2hjb/2hjb_ligand_1.gninatypes # 1.35046 -6.2888
# 10 1 4.3947 2hjb/2hjb_rec.gninatypes 2hjb/2hjb_ligand_2.gninatypes # 1.68832 -6.21503
# 10 1 4.3947 2hjb/2hjb_rec.gninatypes 2hjb/2hjb_ligand_6.gninatypes # 1.57522 -5.50681
# 10 1 4.3947 2hjb/2hjb_rec.gninatypes 2hjb/2hjb_min.gninatypes # 0.328749 -6.06802
# 14 1 2.2291 2igv/2igv_rec.gninatypes 2igv/2igv_ligand_7.gninatypes # 0.689376 -5.52957
# 14 1 2.2291 2igv/2igv_rec.gninatypes 2igv/2igv_ligand_11.gninatypes # 1.73014 -5.19581
# 14 1 2.2291 2igv/2igv_rec.gninatypes 2igv/2igv_min.gninatypes # 0.452382 -4.9782
# 9 1 9.3010 2iw4/2iw4_rec.gninatypes 2iw4/2iw4_ligand_0.gninatypes # 1.12264 -7.52965
# 9 1 9.3010 2iw4/2iw4_rec.gninatypes 2iw4/2iw4_ligand_2.gninatypes # 0.821104 -7.3977
# 9 1 9.3010 2iw4/2iw4_rec.gninatypes 2iw4/2iw4_ligand_7.gninatypes # 1.79239 -7.04854
# 9 1 9.3010 2iw4/2iw4_rec.gninatypes 2iw4/2iw4_min.gninatypes # 0.595518 -7.1635
# 16 1 6.0000 2izl/2izl_rec.gninatypes 2izl/2izl_ligand_0.gninatypes # 0.895432 -8.0699
# 16 1 6.0000 2izl/2izl_rec.gninatypes 2izl/2izl_min.gninatypes # 0.37591 -8.13426
# 9 1 3.5229 2j27/2j27_rec.gninatypes 2j27/2j27_ligand_5.gninatypes # 0.909797 -5.39441
# 9 1 3.5229 2j27/2j27_rec.gninatypes 2j27/2j27_ligand_13.gninatypes # 1.29767 -4.92321
# 9 1 3.5229 2j27/2j27_rec.gninatypes 2j27/2j27_min.gninatypes # 0.544111 -5.26228
# 11 1 6.6478 2j75/2j75_rec.gninatypes 2j75/2j75_ligand_0.gninatypes # 0.244 -7.60977
# 11 1 6.6478 2j75/2j75_rec.gninatypes 2j75/2j75_min.gninatypes # 0.311389 -7.54894
# 11 1 4.8894 2j77/2j77_rec.gninatypes 2j77/2j77_ligand_2.gninatypes # 0.450985 -7.2656
# 11 1 4.8894 2j77/2j77_rec.gninatypes 2j77/2j77_min.gninatypes # 0.3101 -6.19622
# 13 1 5.9586 2j79/2j79_rec.gninatypes 2j79/2j79_ligand_0.gninatypes # 0.267039 -7.89004
# 13 1 5.9586 2j79/2j79_rec.gninatypes 2j79/2j79_ligand_3.gninatypes # 1.70674 -7.41781
# 13 1 5.9586 2j79/2j79_rec.gninatypes 2j79/2j79_min.gninatypes # 0.25271 -7.68185
# 19 1 7.3188 2j7e/2j7e_rec.gninatypes 2j7e/2j7e_min.gninatypes # 0.962564 -6.58509
# 11 1 4.2291 2jke/2jke_rec.gninatypes 2jke/2jke_ligand_0.gninatypes # 0.704347 -6.67361
# 11 1 4.2291 2jke/2jke_rec.gninatypes 2jke/2jke_min.gninatypes # 0.323093 -6.6777
# 18 1 6.3010 2oi2/2oi2_rec.gninatypes 2oi2/2oi2_ligand_7.gninatypes # 1.50869 -6.95672
# 18 1 6.3010 2oi2/2oi2_rec.gninatypes 2oi2/2oi2_ligand_23.gninatypes # 1.48385 -6.56428
# 18 1 6.3010 2oi2/2oi2_rec.gninatypes 2oi2/2oi2_min.gninatypes # 1.6367 -7.48462
# 19 1 6.7645 2on6/2on6_rec.gninatypes 2on6/2on6_ligand_0.gninatypes # 1.47541 -9.2905
# 19 1 6.7645 2on6/2on6_rec.gninatypes 2on6/2on6_min.gninatypes # 0.681869 -8.0383
# 13 1 6.5229 2oxy/2oxy_rec.gninatypes 2oxy/2oxy_ligand_12.gninatypes # 0.612807 -6.36151
# 13 1 6.5229 2oxy/2oxy_rec.gninatypes 2oxy/2oxy_ligand_13.gninatypes # 0.534109 -6.33477
# 13 1 6.5229 2oxy/2oxy_rec.gninatypes 2oxy/2oxy_min.gninatypes # 0.668189 -6.36594
# 20 1 7.4559 2p53/2p53_rec.gninatypes 2p53/2p53_ligand_5.gninatypes # 0.453074 -8.93258
# 20 1 7.4559 2p53/2p53_rec.gninatypes 2p53/2p53_min.gninatypes # 0.91725 -9.53178
# 18 1 8.6990 2pcp/2pcp_rec.gninatypes 2pcp/2pcp_ligand_0.gninatypes # 0.757465 -10.2289
# 18 1 8.6990 2pcp/2pcp_rec.gninatypes 2pcp/2pcp_ligand_2.gninatypes # 0.674664 -9.53762
# 18 1 8.6990 2pcp/2pcp_rec.gninatypes 2pcp/2pcp_min.gninatypes # 0.558409 -10.4177
# 16 1 7.4202 2pou/2pou_rec.gninatypes 2pou/2pou_ligand_0.gninatypes # 0.257858 -8.40064
# 16 1 7.4202 2pou/2pou_rec.gninatypes 2pou/2pou_ligand_3.gninatypes # 1.54955 -7.1121
# 16 1 7.4202 2pou/2pou_rec.gninatypes 2pou/2pou_min.gninatypes # 0.311194 -8.34671
# 12 1 7.2757 2pql/2pql_rec.gninatypes 2pql/2pql_ligand_0.gninatypes # 0.360439 -7.87298
# 12 1 7.2757 2pql/2pql_rec.gninatypes 2pql/2pql_min.gninatypes # 0.185147 -7.88122
# 11 1 4.3979 2pwd/2pwd_rec.gninatypes 2pwd/2pwd_ligand_12.gninatypes # 1.25728 -6.01406
# 11 1 4.3979 2pwd/2pwd_rec.gninatypes 2pwd/2pwd_min.gninatypes # 0.848151 -6.52042
# 13 1 4.8239 2pwg/2pwg_rec.gninatypes 2pwg/2pwg_ligand_3.gninatypes # 0.898536 -6.39709
# 13 1 4.8239 2pwg/2pwg_rec.gninatypes 2pwg/2pwg_min.gninatypes # 0.80502 -6.94172
# 9 1 5.3010 2q7q/2q7q_rec.gninatypes 2q7q/2q7q_ligand_0.gninatypes # 1.15167 -6.45413
# 9 1 5.3010 2q7q/2q7q_rec.gninatypes 2q7q/2q7q_ligand_1.gninatypes # 1.1494 -6.45236
# 9 1 5.3010 2q7q/2q7q_rec.gninatypes 2q7q/2q7q_min.gninatypes # 0.668492 -6.36527
# 10 1 4.1805 2qfu/2qfu_rec.gninatypes 2qfu/2qfu_ligand_0.gninatypes # 0.962084 -6.45522
# 10 1 4.1805 2qfu/2qfu_rec.gninatypes 2qfu/2qfu_min.gninatypes # 0.450116 -6.30762
# 13 1 6.3665 2qpq/2qpq_rec.gninatypes 2qpq/2qpq_ligand_1.gninatypes # 1.60372 -6.54665
# 13 1 6.3665 2qpq/2qpq_rec.gninatypes 2qpq/2qpq_ligand_2.gninatypes # 1.26168 -6.51914
# 13 1 6.3665 2qpq/2qpq_rec.gninatypes 2qpq/2qpq_ligand_3.gninatypes # 1.77544 -6.31533
# 13 1 6.3665 2qpq/2qpq_rec.gninatypes 2qpq/2qpq_ligand_6.gninatypes # 1.81411 -6.16382
# 13 1 6.3665 2qpq/2qpq_rec.gninatypes 2qpq/2qpq_ligand_10.gninatypes # 1.27707 -5.8199
# 13 1 6.3665 2qpq/2qpq_rec.gninatypes 2qpq/2qpq_ligand_11.gninatypes # 1.69207 -5.74534
# 13 1 6.3665 2qpq/2qpq_rec.gninatypes 2qpq/2qpq_min.gninatypes # 0.79201 -6.64833
# 10 1 4.0000 2qrl/2qrl_rec.gninatypes 2qrl/2qrl_min.gninatypes # 1.72536 -3.98422
# 0 1 8.6383 2qry/2qry_rec.gninatypes 2qry/2qry_ligand_0.gninatypes # 1.53475 -9.31969
# 0 1 8.6383 2qry/2qry_rec.gninatypes 2qry/2qry_ligand_5.gninatypes # 1.52652 -8.21704
# 19 1 4.3188 2qtt/2qtt_rec.gninatypes 2qtt/2qtt_ligand_0.gninatypes # 0.579427 -9.53815
# 19 1 4.3188 2qtt/2qtt_rec.gninatypes 2qtt/2qtt_min.gninatypes # 0.604327 -9.19542
# 9 1 3.2218 2ri9/2ri9_rec.gninatypes 2ri9/2ri9_ligand_4.gninatypes # 1.89134 -5.17533
# 9 1 3.2218 2ri9/2ri9_rec.gninatypes 2ri9/2ri9_ligand_9.gninatypes # 1.23227 -4.92554
# 9 1 3.2218 2ri9/2ri9_rec.gninatypes 2ri9/2ri9_ligand_10.gninatypes # 1.70046 -4.91632
# 9 1 3.2218 2ri9/2ri9_rec.gninatypes 2ri9/2ri9_ligand_13.gninatypes # 1.97403 -4.83229
# 9 1 3.2218 2ri9/2ri9_rec.gninatypes 2ri9/2ri9_ligand_17.gninatypes # 1.84647 -4.64579
# 9 1 3.2218 2ri9/2ri9_rec.gninatypes 2ri9/2ri9_min.gninatypes # 0.427201 -4.52447
# 7 1 3.6383 2rk8/2rk8_rec.gninatypes 2rk8/2rk8_ligand_14.gninatypes # 1.92855 -5.39837
# 7 1 3.6383 2rk8/2rk8_rec.gninatypes 2rk8/2rk8_min.gninatypes # 0.634951 -4.89714
# 19 1 3.9031 2rkm/2rkm_rec.gninatypes 2rkm/2rkm_min.gninatypes # 0.382841 -7.09559
# 20 1 3.4202 2sim/2sim_rec.gninatypes 2sim/2sim_ligand_0.gninatypes # 1.83494 -7.60582
# 20 1 3.4202 2sim/2sim_rec.gninatypes 2sim/2sim_ligand_1.gninatypes # 1.1584 -7.48075
# 20 1 3.4202 2sim/2sim_rec.gninatypes 2sim/2sim_min.gninatypes # 0.44883 -7.45155
# 13 1 5.8861 2tmn/2tmn_rec.gninatypes 2tmn/2tmn_ligand_0.gninatypes # 0.682714 -7.59757
# 13 1 5.8861 2tmn/2tmn_rec.gninatypes 2tmn/2tmn_min.gninatypes # 0.769397 -5.80067
# 13 1 4.6778 2uy4/2uy4_rec.gninatypes 2uy4/2uy4_ligand_1.gninatypes # 1.85938 -5.5178
# 13 1 4.6778 2uy4/2uy4_rec.gninatypes 2uy4/2uy4_min.gninatypes # 0.588911 -5.2745
# 7 1 3.0000 2v3u/2v3u_rec.gninatypes 2v3u/2v3u_ligand_0.gninatypes # 0.780513 -5.81082
# 7 1 3.0000 2v3u/2v3u_rec.gninatypes 2v3u/2v3u_min.gninatypes # 0.295887 -5.57097
# 20 1 9.0862 2v58/2v58_rec.gninatypes 2v58/2v58_ligand_0.gninatypes # 0.287447 -8.93795
# 20 1 9.0862 2v58/2v58_rec.gninatypes 2v58/2v58_ligand_1.gninatypes # 0.248983 -8.91137
# 20 1 9.0862 2v58/2v58_rec.gninatypes 2v58/2v58_min.gninatypes # 0.265476 -8.90873
# 14 1 4.6021 2vb8/2vb8_rec.gninatypes 2vb8/2vb8_ligand_2.gninatypes # 1.39844 -7.36633
# 14 1 4.6021 2vb8/2vb8_rec.gninatypes 2vb8/2vb8_min.gninatypes # 0.385629 -6.99848
# 16 1 4.6021 2vba/2vba_rec.gninatypes 2vba/2vba_ligand_2.gninatypes # 0.881728 -6.54121
# 16 1 4.6021 2vba/2vba_rec.gninatypes 2vba/2vba_min.gninatypes # 0.887347 -7.00917
# 14 1 8.4437 2vc9/2vc9_rec.gninatypes 2vc9/2vc9_min.gninatypes # 0.644589 -6.4374
# 12 1 6.8861 2vk2/2vk2_rec.gninatypes 2vk2/2vk2_ligand_0.gninatypes # 0.309306 -8.35659
# 12 1 6.8861 2vk2/2vk2_rec.gninatypes 2vk2/2vk2_min.gninatypes # 0.607861 -8.35823
# 20 1 5.3010 2vk6/2vk6_rec.gninatypes 2vk6/2vk6_ligand_0.gninatypes # 1.01383 -8.01037
# 20 1 5.3010 2vk6/2vk6_rec.gninatypes 2vk6/2vk6_ligand_1.gninatypes # 1.65527 -7.82915
# 20 1 5.3010 2vk6/2vk6_rec.gninatypes 2vk6/2vk6_ligand_6.gninatypes # 1.54161 -7.23021
# 20 1 5.3010 2vk6/2vk6_rec.gninatypes 2vk6/2vk6_min.gninatypes # 0.428871 -8.03094
# 15 1 2.9393 2vmc/2vmc_rec.gninatypes 2vmc/2vmc_ligand_9.gninatypes # 0.755421 -5.17058
# 15 1 2.9393 2vmc/2vmc_rec.gninatypes 2vmc/2vmc_min.gninatypes # 0.775681 -5.15987
# 13 1 3.0223 2vmd/2vmd_rec.gninatypes 2vmd/2vmd_ligand_0.gninatypes # 0.954662 -5.07922
# 13 1 3.0223 2vmd/2vmd_rec.gninatypes 2vmd/2vmd_ligand_1.gninatypes # 1.38614 -5.03708
# 13 1 3.0223 2vmd/2vmd_rec.gninatypes 2vmd/2vmd_min.gninatypes # 0.812243 -4.59597
# 20 1 4.8861 2vo5/2vo5_rec.gninatypes 2vo5/2vo5_ligand_0.gninatypes # 0.60827 -9.64279
# 20 1 4.8861 2vo5/2vo5_rec.gninatypes 2vo5/2vo5_min.gninatypes # 0.492397 -9.37986
# 14 1 3.3979 2vvp/2vvp_rec.gninatypes 2vvp/2vvp_ligand_0.gninatypes # 1.33813 -7.7532
# 14 1 3.3979 2vvp/2vvp_rec.gninatypes 2vvp/2vvp_ligand_4.gninatypes # 1.70045 -7.56148
# 14 1 3.3979 2vvp/2vvp_rec.gninatypes 2vvp/2vvp_ligand_6.gninatypes # 1.86019 -7.47058
# 14 1 3.3979 2vvp/2vvp_rec.gninatypes 2vvp/2vvp_ligand_11.gninatypes # 1.6882 -6.83297
# 14 1 3.3979 2vvp/2vvp_rec.gninatypes 2vvp/2vvp_ligand_12.gninatypes # 1.6636 -6.82462
# 14 1 3.3979 2vvp/2vvp_rec.gninatypes 2vvp/2vvp_min.gninatypes # 0.770265 -7.02566
# 20 1 3.5229 2vw1/2vw1_rec.gninatypes 2vw1/2vw1_ligand_0.gninatypes # 0.706402 -8.19504
# 20 1 3.5229 2vw1/2vw1_rec.gninatypes 2vw1/2vw1_min.gninatypes # 0.448727 -8.48807
# 13 1 3.3010 2vw2/2vw2_rec.gninatypes 2vw2/2vw2_ligand_0.gninatypes # 1.03563 -7.26627
# 13 1 3.3010 2vw2/2vw2_rec.gninatypes 2vw2/2vw2_ligand_1.gninatypes # 1.66646 -6.77403
# 13 1 3.3010 2vw2/2vw2_rec.gninatypes 2vw2/2vw2_ligand_2.gninatypes # 1.36257 -6.69506
# 13 1 3.3010 2vw2/2vw2_rec.gninatypes 2vw2/2vw2_ligand_4.gninatypes # 1.79596 -6.55273
# 13 1 3.3010 2vw2/2vw2_rec.gninatypes 2vw2/2vw2_ligand_5.gninatypes # 1.58942 -6.52506
# 10 1 5.0000 2vxn/2vxn_rec.gninatypes 2vxn/2vxn_ligand_1.gninatypes # 1.43962 -5.95045
# 10 1 5.0000 2vxn/2vxn_rec.gninatypes 2vxn/2vxn_min.gninatypes # 0.567554 -6.19944
# 18 1 4.8539 2w4x/2w4x_rec.gninatypes 2w4x/2w4x_min.gninatypes # 0.659424 -7.94217
# 11 1 6.5031 2weg/2weg_rec.gninatypes 2weg/2weg_ligand_0.gninatypes # 0.430536 -6.86159
# 11 1 6.5031 2weg/2weg_rec.gninatypes 2weg/2weg_min.gninatypes # 0.463983 -6.85746
# 11 1 5.9488 2weh/2weh_rec.gninatypes 2weh/2weh_ligand_0.gninatypes # 1.94701 -7.08927
# 11 1 5.9488 2weh/2weh_rec.gninatypes 2weh/2weh_ligand_2.gninatypes # 0.277571 -6.37267
# 11 1 5.9488 2weh/2weh_rec.gninatypes 2weh/2weh_min.gninatypes # 0.240907 -6.45558
# 10 1 6.0762 2wej/2wej_rec.gninatypes 2wej/2wej_ligand_0.gninatypes # 0.421377 -6.38873
# 10 1 6.0762 2wej/2wej_rec.gninatypes 2wej/2wej_ligand_1.gninatypes # 0.431043 -6.38701
# 10 1 6.0762 2wej/2wej_rec.gninatypes 2wej/2wej_min.gninatypes # 0.382567 -6.39538
# 18 1 4.0000 2whp/2whp_rec.gninatypes 2whp/2whp_ligand_0.gninatypes # 1.03415 -8.34081
# 18 1 4.0000 2whp/2whp_rec.gninatypes 2whp/2whp_ligand_2.gninatypes # 1.56019 -8.2168
# 18 1 4.0000 2whp/2whp_rec.gninatypes 2whp/2whp_ligand_3.gninatypes # 1.76378 -7.82331
# 18 1 4.0000 2whp/2whp_rec.gninatypes 2whp/2whp_min.gninatypes # 0.779019 -8.08173
# 14 1 7.9586 2x8z/2x8z_rec.gninatypes 2x8z/2x8z_min.gninatypes # 0.901498 -5.86859
# 16 1 3.1024 2xdl/2xdl_rec.gninatypes 2xdl/2xdl_ligand_1.gninatypes # 0.717948 -6.56633
# 16 1 3.1024 2xdl/2xdl_rec.gninatypes 2xdl/2xdl_min.gninatypes # 0.377413 -6.69512
# 16 1 6.4559 2xdx/2xdx_rec.gninatypes 2xdx/2xdx_ligand_10.gninatypes # 0.461966 -6.67099
# 16 1 6.4559 2xdx/2xdx_rec.gninatypes 2xdx/2xdx_ligand_16.gninatypes # 0.720594 -6.27539
# 16 1 6.4559 2xdx/2xdx_rec.gninatypes 2xdx/2xdx_min.gninatypes # 0.442434 -6.68719
# 15 1 5.0706 2xm1/2xm1_rec.gninatypes 2xm1/2xm1_ligand_0.gninatypes # 0.789864 -8.44456
# 15 1 5.0706 2xm1/2xm1_rec.gninatypes 2xm1/2xm1_min.gninatypes # 0.446354 -8.28155
# 18 1 5.9215 2xn3/2xn3_rec.gninatypes 2xn3/2xn3_ligand_0.gninatypes # 0.730181 -8.88441
# 18 1 5.9215 2xn3/2xn3_rec.gninatypes 2xn3/2xn3_ligand_1.gninatypes # 1.92805 -8.54154
# 18 1 5.9215 2xn3/2xn3_rec.gninatypes 2xn3/2xn3_min.gninatypes # 0.781034 -8.88749
# 17 1 5.7696 2xp7/2xp7_rec.gninatypes 2xp7/2xp7_ligand_0.gninatypes # 0.679871 -7.27942
# 17 1 5.7696 2xp7/2xp7_rec.gninatypes 2xp7/2xp7_ligand_1.gninatypes # 0.672261 -7.27673
# 17 1 5.7696 2xp7/2xp7_rec.gninatypes 2xp7/2xp7_ligand_2.gninatypes # 0.691856 -6.95819
# 17 1 5.7696 2xp7/2xp7_rec.gninatypes 2xp7/2xp7_ligand_3.gninatypes # 0.701472 -6.9431
# 17 1 5.7696 2xp7/2xp7_rec.gninatypes 2xp7/2xp7_ligand_4.gninatypes # 1.19091 -6.35153
# 17 1 5.7696 2xp7/2xp7_rec.gninatypes 2xp7/2xp7_ligand_5.gninatypes # 1.32874 -6.13942
# 17 1 5.7696 2xp7/2xp7_rec.gninatypes 2xp7/2xp7_ligand_6.gninatypes # 1.89757 -5.96114
# 17 1 5.7696 2xp7/2xp7_rec.gninatypes 2xp7/2xp7_ligand_12.gninatypes # 1.45213 -5.59287
# 17 1 5.7696 2xp7/2xp7_rec.gninatypes 2xp7/2xp7_min.gninatypes # 0.288104 -7.19292
# 12 1 5.5376 2y7i/2y7i_rec.gninatypes 2y7i/2y7i_ligand_0.gninatypes # 0.789964 -7.30595
# 12 1 5.5376 2y7i/2y7i_rec.gninatypes 2y7i/2y7i_min.gninatypes # 0.340938 -6.87288
# 10 1 5.4685 2y7p/2y7p_rec.gninatypes 2y7p/2y7p_ligand_0.gninatypes # 0.868735 -6.76319
# 10 1 5.4685 2y7p/2y7p_rec.gninatypes 2y7p/2y7p_ligand_1.gninatypes # 1.15047 -6.75725
# 10 1 5.4685 2y7p/2y7p_rec.gninatypes 2y7p/2y7p_ligand_2.gninatypes # 0.338332 -6.73729
# 10 1 5.4685 2y7p/2y7p_rec.gninatypes 2y7p/2y7p_ligand_6.gninatypes # 1.60562 -6.30025
# 10 1 5.4685 2y7p/2y7p_rec.gninatypes 2y7p/2y7p_min.gninatypes # 0.406514 -6.80495
# 20 1 5.1367 2yaz/2yaz_rec.gninatypes 2yaz/2yaz_ligand_0.gninatypes # 0.435871 -10.672
# 20 1 5.1367 2yaz/2yaz_rec.gninatypes 2yaz/2yaz_ligand_1.gninatypes # 1.69326 -9.12587
# 20 1 5.1367 2yaz/2yaz_rec.gninatypes 2yaz/2yaz_min.gninatypes # 0.45577 -10.4727
# 16 1 3.8539 2yb0/2yb0_rec.gninatypes 2yb0/2yb0_ligand_0.gninatypes # 0.463384 -8.25255
# 16 1 3.8539 2yb0/2yb0_rec.gninatypes 2yb0/2yb0_min.gninatypes # 0.337388 -8.7202
# 15 1 5.6021 2yhw/2yhw_rec.gninatypes 2yhw/2yhw_min.gninatypes # 0.231295 -8.47149
# 7 1 7.6778 2yln/2yln_rec.gninatypes 2yln/2yln_ligand_4.gninatypes # 1.05114 -4.2885
# 7 1 7.6778 2yln/2yln_rec.gninatypes 2yln/2yln_min.gninatypes # 0.746453 -4.33077
# 9 1 5.8539 2z94/2z94_rec.gninatypes 2z94/2z94_min.gninatypes # 1.92789 -2.52953
# 10 1 4.1506 3a9i/3a9i_rec.gninatypes 3a9i/3a9i_ligand_5.gninatypes # 1.88722 -5.3726
# 10 1 4.1506 3a9i/3a9i_rec.gninatypes 3a9i/3a9i_min.gninatypes # 0.46803 -5.13962
# 13 1 3.0301 3adv/3adv_rec.gninatypes 3adv/3adv_min.gninatypes # 1.16971 -5.3205
# 10 1 2.2596 3ao1/3ao1_rec.gninatypes 3ao1/3ao1_min.gninatypes # 0.474588 -5.24758
# 17 1 3.7696 3ao2/3ao2_rec.gninatypes 3ao2/3ao2_ligand_0.gninatypes # 0.528874 -7.62688
# 17 1 3.7696 3ao2/3ao2_rec.gninatypes 3ao2/3ao2_min.gninatypes # 0.48638 -7.67517
# 16 1 2.0706 3ao4/3ao4_rec.gninatypes 3ao4/3ao4_ligand_0.gninatypes # 0.506255 -7.8184
# 16 1 2.0706 3ao4/3ao4_rec.gninatypes 3ao4/3ao4_ligand_7.gninatypes # 1.77593 -6.93553
# 16 1 2.0706 3ao4/3ao4_rec.gninatypes 3ao4/3ao4_min.gninatypes # 0.521799 -7.81862
# 20 1 5.3979 3arr/3arr_rec.gninatypes 3arr/3arr_ligand_3.gninatypes # 1.69417 -7.12763
# 20 1 5.3979 3arr/3arr_rec.gninatypes 3arr/3arr_min.gninatypes # 1.68267 -7.19399
# 20 1 3.2218 3aru/3aru_rec.gninatypes 3aru/3aru_ligand_10.gninatypes # 1.65992 -6.56161
# 20 1 3.2218 3aru/3aru_rec.gninatypes 3aru/3aru_min.gninatypes # 0.515638 -6.10892
# 18 1 6.0655 3b25/3b25_rec.gninatypes 3b25/3b25_ligand_0.gninatypes # 0.554105 -9.18043
# 18 1 6.0655 3b25/3b25_rec.gninatypes 3b25/3b25_ligand_1.gninatypes # 1.71219 -8.88253
# 18 1 6.0655 3b25/3b25_rec.gninatypes 3b25/3b25_ligand_2.gninatypes # 1.32964 -8.78912
# 18 1 6.0655 3b25/3b25_rec.gninatypes 3b25/3b25_ligand_3.gninatypes # 1.31896 -8.7737
# 18 1 6.0655 3b25/3b25_rec.gninatypes 3b25/3b25_ligand_8.gninatypes # 1.03145 -8.07558
# 18 1 6.0655 3b25/3b25_rec.gninatypes 3b25/3b25_min.gninatypes # 0.579055 -9.21745
# ...
# 16 1 4.3188 4u43/4u43_rec.gninatypes 4u43/4u43_min.gninatypes # 1.03573 -7.1073
# 14 1 5.0088 4u4x/4u4x_rec.gninatypes 4u4x/4u4x_ligand_0.gninatypes # 0.684661 -6.44416
# 14 1 5.0088 4u4x/4u4x_rec.gninatypes 4u4x/4u4x_ligand_12.gninatypes # 1.33098 -5.9821
# 14 1 5.0088 4u4x/4u4x_rec.gninatypes 4u4x/4u4x_min.gninatypes # 0.261052 -6.36609
# 15 1 2.0605 4u54/4u54_rec.gninatypes 4u54/4u54_ligand_5.gninatypes # 1.22245 -4.99215
# 15 1 2.0605 4u54/4u54_rec.gninatypes 4u54/4u54_min.gninatypes # 0.938406 -4.99676
# 11 1 4.2612 4u69/4u69_rec.gninatypes 4u69/4u69_ligand_1.gninatypes # 0.84925 -7.87945
# 11 1 4.2612 4u69/4u69_rec.gninatypes 4u69/4u69_ligand_2.gninatypes # 1.96045 -7.28262
# 11 1 4.2612 4u69/4u69_rec.gninatypes 4u69/4u69_ligand_3.gninatypes # 1.55876 -7.21161
# 11 1 4.2612 4u69/4u69_rec.gninatypes 4u69/4u69_min.gninatypes # 0.636484 -7.37761
# 13 1 5.0044 4u6c/4u6c_rec.gninatypes 4u6c/4u6c_ligand_0.gninatypes # 0.864579 -9.08684
# 13 1 5.0044 4u6c/4u6c_rec.gninatypes 4u6c/4u6c_ligand_1.gninatypes # 1.40589 -8.58918
# 13 1 5.0044 4u6c/4u6c_rec.gninatypes 4u6c/4u6c_ligand_2.gninatypes # 1.82664 -8.06035
# 13 1 5.0044 4u6c/4u6c_rec.gninatypes 4u6c/4u6c_ligand_3.gninatypes # 1.43495 -7.85166
# 13 1 5.0044 4u6c/4u6c_rec.gninatypes 4u6c/4u6c_ligand_4.gninatypes # 1.89587 -7.21171
# 13 1 5.0044 4u6c/4u6c_rec.gninatypes 4u6c/4u6c_min.gninatypes # 0.656455 -7.90016
# 13 1 4.2125 4u6w/4u6w_rec.gninatypes 4u6w/4u6w_ligand_0.gninatypes # 0.831603 -8.06088
# 13 1 4.2125 4u6w/4u6w_rec.gninatypes 4u6w/4u6w_ligand_1.gninatypes # 0.736068 -7.78858
# 13 1 4.2125 4u6w/4u6w_rec.gninatypes 4u6w/4u6w_ligand_2.gninatypes # 1.77983 -7.64718
# 13 1 4.2125 4u6w/4u6w_rec.gninatypes 4u6w/4u6w_ligand_6.gninatypes # 1.41603 -6.2915
# 13 1 4.2125 4u6w/4u6w_rec.gninatypes 4u6w/4u6w_min.gninatypes # 0.864377 -7.87711
# 11 1 5.4089 4u6z/4u6z_rec.gninatypes 4u6z/4u6z_ligand_0.gninatypes # 1.28788 -7.49336
# 11 1 5.4089 4u6z/4u6z_rec.gninatypes 4u6z/4u6z_ligand_1.gninatypes # 1.50494 -7.36939
# 11 1 5.4089 4u6z/4u6z_rec.gninatypes 4u6z/4u6z_ligand_2.gninatypes # 1.21543 -7.20254
# 11 1 5.4089 4u6z/4u6z_rec.gninatypes 4u6z/4u6z_ligand_3.gninatypes # 1.72017 -6.82079
# 11 1 5.4089 4u6z/4u6z_rec.gninatypes 4u6z/4u6z_ligand_4.gninatypes # 1.42553 -6.81543
# 11 1 5.4089 4u6z/4u6z_rec.gninatypes 4u6z/4u6z_min.gninatypes # 0.941299 -7.24338
# 13 1 5.0223 4u70/4u70_rec.gninatypes 4u70/4u70_ligand_0.gninatypes # 0.889462 -8.66746
# 13 1 5.0223 4u70/4u70_rec.gninatypes 4u70/4u70_ligand_1.gninatypes # 0.88745 -8.58596
# 13 1 5.0223 4u70/4u70_rec.gninatypes 4u70/4u70_ligand_2.gninatypes # 0.982332 -8.34548
# 13 1 5.0223 4u70/4u70_rec.gninatypes 4u70/4u70_ligand_3.gninatypes # 1.24805 -8.1691
# 13 1 5.0223 4u70/4u70_rec.gninatypes 4u70/4u70_ligand_4.gninatypes # 1.83299 -6.92957
# 13 1 5.0223 4u70/4u70_rec.gninatypes 4u70/4u70_min.gninatypes # 0.50052 -8.11839
# 12 1 5.2218 4u71/4u71_rec.gninatypes 4u71/4u71_ligand_0.gninatypes # 0.925055 -7.96867
# 12 1 5.2218 4u71/4u71_rec.gninatypes 4u71/4u71_ligand_1.gninatypes # 1.01849 -7.94536
# 12 1 5.2218 4u71/4u71_rec.gninatypes 4u71/4u71_ligand_2.gninatypes # 1.10753 -7.73794
# 12 1 5.2218 4u71/4u71_rec.gninatypes 4u71/4u71_ligand_3.gninatypes # 1.81729 -7.20062
# 12 1 5.2218 4u71/4u71_rec.gninatypes 4u71/4u71_ligand_4.gninatypes # 1.27328 -6.92186
# 12 1 5.2218 4u71/4u71_rec.gninatypes 4u71/4u71_min.gninatypes # 0.878409 -8.44109
# 12 1 5.1805 4u73/4u73_rec.gninatypes 4u73/4u73_ligand_0.gninatypes # 0.955154 -8.6912
# 12 1 5.1805 4u73/4u73_rec.gninatypes 4u73/4u73_ligand_1.gninatypes # 0.977887 -8.62785
# 12 1 5.1805 4u73/4u73_rec.gninatypes 4u73/4u73_ligand_2.gninatypes # 1.02303 -8.26934
# 12 1 5.1805 4u73/4u73_rec.gninatypes 4u73/4u73_ligand_5.gninatypes # 1.81527 -7.16351
# 12 1 5.1805 4u73/4u73_rec.gninatypes 4u73/4u73_min.gninatypes # 1.00786 -7.95929
# 11 1 4.2840 4ufj/4ufj_rec.gninatypes 4ufj/4ufj_ligand_0.gninatypes # 0.267129 -8.01948
# 11 1 4.2840 4ufj/4ufj_rec.gninatypes 4ufj/4ufj_min.gninatypes # 0.295555 -8.08994
# 9 1 3.8861 4ufk/4ufk_rec.gninatypes 4ufk/4ufk_ligand_2.gninatypes # 0.610917 -6.00649
# 9 1 3.8861 4ufk/4ufk_rec.gninatypes 4ufk/4ufk_ligand_7.gninatypes # 1.682 -5.08125
# 9 1 3.8861 4ufk/4ufk_rec.gninatypes 4ufk/4ufk_min.gninatypes # 0.49516 -6.21323
# 11 1 3.7212 4ufm/4ufm_rec.gninatypes 4ufm/4ufm_ligand_0.gninatypes # 0.321042 -7.68266
# 11 1 3.7212 4ufm/4ufm_rec.gninatypes 4ufm/4ufm_ligand_4.gninatypes # 1.87951 -6.21092
# 11 1 3.7212 4ufm/4ufm_rec.gninatypes 4ufm/4ufm_min.gninatypes # 0.31546 -7.69593
# 12 1 2.6021 4up5/4up5_rec.gninatypes 4up5/4up5_ligand_2.gninatypes # 0.22835 -4.87079
# 12 1 2.6021 4up5/4up5_rec.gninatypes 4up5/4up5_ligand_8.gninatypes # 1.79152 -4.31565
# 12 1 2.6021 4up5/4up5_rec.gninatypes 4up5/4up5_min.gninatypes # 0.296972 -4.8934
# 16 1 2.2218 4ury/4ury_rec.gninatypes 4ury/4ury_ligand_1.gninatypes # 0.728245 -7.39169
# 16 1 2.2218 4ury/4ury_rec.gninatypes 4ury/4ury_min.gninatypes # 0.679823 -7.42249
# 17 1 2.5229 4urz/4urz_rec.gninatypes 4urz/4urz_ligand_1.gninatypes # 0.858419 -8.63016
# 17 1 2.5229 4urz/4urz_rec.gninatypes 4urz/4urz_min.gninatypes # 0.749015 -8.37964
# 15 1 5.3188 4us3/4us3_rec.gninatypes 4us3/4us3_ligand_0.gninatypes # 0.443445 -10.0601
# 15 1 5.3188 4us3/4us3_rec.gninatypes 4us3/4us3_min.gninatypes # 0.31688 -9.95476
# 6 1 3.7570 4w52/4w52_rec.gninatypes 4w52/4w52_ligand_0.gninatypes # 0.84274 -5.43254
# 6 1 3.7570 4w52/4w52_rec.gninatypes 4w52/4w52_ligand_1.gninatypes # 0.868163 -5.42884
# 6 1 3.7570 4w52/4w52_rec.gninatypes 4w52/4w52_ligand_2.gninatypes # 0.855518 -5.42877
# 6 1 3.7570 4w52/4w52_rec.gninatypes 4w52/4w52_ligand_3.gninatypes # 0.884746 -5.4268
# 6 1 3.7570 4w52/4w52_rec.gninatypes 4w52/4w52_ligand_4.gninatypes # 0.870778 -5.42469
# 6 1 3.7570 4w52/4w52_rec.gninatypes 4w52/4w52_ligand_5.gninatypes # 0.877783 -5.41686
# 6 1 3.7570 4w52/4w52_rec.gninatypes 4w52/4w52_ligand_6.gninatypes # 0.857761 -5.41414
# 6 1 3.7570 4w52/4w52_rec.gninatypes 4w52/4w52_min.gninatypes # 0.270047 -5.17617
# 9 1 4.1249 4whs/4whs_rec.gninatypes 4whs/4whs_min.gninatypes # 0.416096 -4.51554
# 20 1 9.7212 4wkn/4wkn_rec.gninatypes 4wkn/4wkn_ligand_0.gninatypes # 1.00252 -8.8809
# 20 1 9.7212 4wkn/4wkn_rec.gninatypes 4wkn/4wkn_min.gninatypes # 0.58279 -8.23159
# 18 1 11.6990 4wr7/4wr7_rec.gninatypes 4wr7/4wr7_ligand_0.gninatypes # 0.942919 -7.57774
# 18 1 11.6990 4wr7/4wr7_rec.gninatypes 4wr7/4wr7_ligand_1.gninatypes # 0.955761 -7.56415
# 18 1 11.6990 4wr7/4wr7_rec.gninatypes 4wr7/4wr7_ligand_2.gninatypes # 1.8268 -7.43158
# 18 1 11.6990 4wr7/4wr7_rec.gninatypes 4wr7/4wr7_ligand_3.gninatypes # 1.71726 -7.39131
# 18 1 11.6990 4wr7/4wr7_rec.gninatypes 4wr7/4wr7_ligand_4.gninatypes # 1.8547 -7.19979
# 18 1 11.6990 4wr7/4wr7_rec.gninatypes 4wr7/4wr7_ligand_7.gninatypes # 1.81211 -6.44589
# 18 1 11.6990 4wr7/4wr7_rec.gninatypes 4wr7/4wr7_min.gninatypes # 0.545373 -7.87504
# 14 1 9.8239 4wup/4wup_rec.gninatypes 4wup/4wup_ligand_0.gninatypes # 1.32683 -6.28833
# 14 1 9.8239 4wup/4wup_rec.gninatypes 4wup/4wup_ligand_1.gninatypes # 1.31962 -6.28757
# 14 1 9.8239 4wup/4wup_rec.gninatypes 4wup/4wup_ligand_3.gninatypes # 0.864444 -6.13242
# 14 1 9.8239 4wup/4wup_rec.gninatypes 4wup/4wup_ligand_6.gninatypes # 1.3336 -5.90191
# 14 1 9.8239 4wup/4wup_rec.gninatypes 4wup/4wup_min.gninatypes # 0.853136 -6.47561
# 18 1 10.2076 4ww6/4ww6_rec.gninatypes 4ww6/4ww6_ligand_0.gninatypes # 0.504752 -7.61561
# 18 1 10.2076 4ww6/4ww6_rec.gninatypes 4ww6/4ww6_ligand_1.gninatypes # 0.540528 -7.59877
# 18 1 10.2076 4ww6/4ww6_rec.gninatypes 4ww6/4ww6_ligand_2.gninatypes # 1.46635 -6.93452
# 18 1 10.2076 4ww6/4ww6_rec.gninatypes 4ww6/4ww6_ligand_3.gninatypes # 1.58771 -6.80457
# 18 1 10.2076 4ww6/4ww6_rec.gninatypes 4ww6/4ww6_min.gninatypes # 0.541877 -7.78297
# 14 1 10.1739 4ww8/4ww8_rec.gninatypes 4ww8/4ww8_ligand_1.gninatypes # 0.383776 -6.43374
# 14 1 10.1739 4ww8/4ww8_rec.gninatypes 4ww8/4ww8_ligand_2.gninatypes # 0.34922 -6.41017
# 14 1 10.1739 4ww8/4ww8_rec.gninatypes 4ww8/4ww8_ligand_9.gninatypes # 1.70131 -5.84744
# 14 1 10.1739 4ww8/4ww8_rec.gninatypes 4ww8/4ww8_ligand_10.gninatypes # 0.627692 -5.84285
# 14 1 10.1739 4ww8/4ww8_rec.gninatypes 4ww8/4ww8_min.gninatypes # 0.533871 -6.77824
# 13 1 7.1445 4xaq/4xaq_rec.gninatypes 4xaq/4xaq_ligand_0.gninatypes # 0.416028 -8.75026
# 13 1 7.1445 4xaq/4xaq_rec.gninatypes 4xaq/4xaq_ligand_2.gninatypes # 1.49718 -7.78003
# 13 1 7.1445 4xaq/4xaq_rec.gninatypes 4xaq/4xaq_min.gninatypes # 0.660279 -8.5786
# 13 1 6.9706 4xar/4xar_rec.gninatypes 4xar/4xar_ligand_0.gninatypes # 0.565879 -8.91694
# 13 1 6.9706 4xar/4xar_rec.gninatypes 4xar/4xar_ligand_1.gninatypes # 1.47587 -7.98987
# 13 1 6.9706 4xar/4xar_rec.gninatypes 4xar/4xar_ligand_5.gninatypes # 1.76801 -6.8084
# 13 1 6.9706 4xar/4xar_rec.gninatypes 4xar/4xar_min.gninatypes # 0.660876 -8.75695
# 15 1 6.5850 4xas/4xas_rec.gninatypes 4xas/4xas_ligand_0.gninatypes # 0.527199 -9.43305
# 15 1 6.5850 4xas/4xas_rec.gninatypes 4xas/4xas_min.gninatypes # 0.46485 -8.91336
# 9 1 4.0655 4xmr/4xmr_rec.gninatypes 4xmr/4xmr_ligand_0.gninatypes # 1.35552 -6.71426
# 9 1 4.0655 4xmr/4xmr_rec.gninatypes 4xmr/4xmr_ligand_1.gninatypes # 1.82875 -6.54558
# 9 1 4.0655 4xmr/4xmr_rec.gninatypes 4xmr/4xmr_min.gninatypes # 0.510047 -6.28826
# 20 1 5.2366 4y59/4y59_rec.gninatypes 4y59/4y59_ligand_0.gninatypes # 1.15417 -11.077
# 20 1 5.2366 4y59/4y59_rec.gninatypes 4y59/4y59_min.gninatypes # 0.888721 -11.0092
# 20 1 5.9208 4y5d/4y5d_rec.gninatypes 4y5d/4y5d_ligand_0.gninatypes # 1.04574 -10.8595
# 20 1 5.9208 4y5d/4y5d_rec.gninatypes 4y5d/4y5d_min.gninatypes # 0.614585 -10.6966
# 15 1 4.1308 4yc0/4yc0_rec.gninatypes 4yc0/4yc0_ligand_0.gninatypes # 0.751137 -9.17447
# 15 1 4.1308 4yc0/4yc0_rec.gninatypes 4yc0/4yc0_min.gninatypes # 0.73692 -9.13243
# 13 1 7.6778 4ygf/4ygf_rec.gninatypes 4ygf/4ygf_ligand_1.gninatypes # 1.83284 -5.7141
# 13 1 7.6778 4ygf/4ygf_rec.gninatypes 4ygf/4ygf_ligand_4.gninatypes # 1.70209 -5.49289
# 0 1 6.6478 4yha/4yha_rec.gninatypes 4yha/4yha_ligand_7.gninatypes # 1.96312 -5.13502
# 6 1 4.4318 4ykj/4ykj_rec.gninatypes 4ykj/4ykj_ligand_0.gninatypes # 0.303953 -4.95716
# 6 1 4.4318 4ykj/4ykj_rec.gninatypes 4ykj/4ykj_min.gninatypes # 0.271565 -5.01673
# 7 1 2.7696 4ykk/4ykk_rec.gninatypes 4ykk/4ykk_min.gninatypes # 0.278242 -4.7383
# 20 1 6.2076 4ymb/4ymb_rec.gninatypes 4ymb/4ymb_ligand_0.gninatypes # 0.658731 -8.73588
# 20 1 6.2076 4ymb/4ymb_rec.gninatypes 4ymb/4ymb_min.gninatypes # 0.710686 -8.2439
# 20 1 8.3468 4yml/4yml_rec.gninatypes 4yml/4yml_ligand_0.gninatypes # 0.8799 -9.20447
# 20 1 8.3468 4yml/4yml_rec.gninatypes 4yml/4yml_ligand_2.gninatypes # 1.82259 -6.75889
# 20 1 8.3468 4yml/4yml_rec.gninatypes 4yml/4yml_min.gninatypes # 0.79267 -9.31501
# 20 1 10.5229 4yo8/4yo8_rec.gninatypes 4yo8/4yo8_ligand_0.gninatypes # 1.09515 -9.375
# 20 1 10.5229 4yo8/4yo8_rec.gninatypes 4yo8/4yo8_min.gninatypes # 0.610917 -9.2824
# 14 1 5.8761 4zei/4zei_rec.gninatypes 4zei/4zei_ligand_0.gninatypes # 0.789533 -8.87493
# 14 1 5.8761 4zei/4zei_rec.gninatypes 4zei/4zei_ligand_1.gninatypes # 0.78716 -8.74959
# 14 1 5.8761 4zei/4zei_rec.gninatypes 4zei/4zei_min.gninatypes # 0.524552 -7.48021
# 17 1 5.6576 4zek/4zek_rec.gninatypes 4zek/4zek_ligand_0.gninatypes # 0.875852 -7.49662
# 17 1 5.6576 4zek/4zek_rec.gninatypes 4zek/4zek_ligand_1.gninatypes # 1.26919 -7.46033
# 17 1 5.6576 4zek/4zek_rec.gninatypes 4zek/4zek_min.gninatypes # 0.574985 -8.44852
# 19 1 4.3010 4zme/4zme_rec.gninatypes 4zme/4zme_ligand_1.gninatypes # 1.27818 -7.31065
# 19 1 4.3010 4zme/4zme_rec.gninatypes 4zme/4zme_min.gninatypes # 0.520257 -6.88392
# 20 1 4.1249 4zow/4zow_rec.gninatypes 4zow/4zow_ligand_3.gninatypes # 0.65313 -6.75265
# 20 1 4.1249 4zow/4zow_rec.gninatypes 4zow/4zow_ligand_5.gninatypes # 1.98786 -6.68995
# 20 1 4.1249 4zow/4zow_rec.gninatypes 4zow/4zow_ligand_10.gninatypes # 1.34151 -6.62248
# 20 1 4.1249 4zow/4zow_rec.gninatypes 4zow/4zow_min.gninatypes # 0.932755 -6.38812
# 18 1 6.9031 4zzx/4zzx_rec.gninatypes 4zzx/4zzx_ligand_1.gninatypes # 1.57849 -8.0295
# 18 1 6.9031 4zzx/4zzx_rec.gninatypes 4zzx/4zzx_ligand_3.gninatypes # 1.81893 -8.02527
# 18 1 6.9031 4zzx/4zzx_rec.gninatypes 4zzx/4zzx_min.gninatypes # 0.494967 -7.28905
# 16 1 3.0269 5aoi/5aoi_rec.gninatypes 5aoi/5aoi_ligand_2.gninatypes # 0.542929 -6.11087
# 16 1 3.0269 5aoi/5aoi_rec.gninatypes 5aoi/5aoi_min.gninatypes # 0.729767 -6.19607
# 17 1 4.6778 5aoj/5aoj_rec.gninatypes 5aoj/5aoj_ligand_0.gninatypes # 0.806436 -6.02569
# 17 1 4.6778 5aoj/5aoj_rec.gninatypes 5aoj/5aoj_min.gninatypes # 0.649651 -6.08259
# 13 1 2.3188 5aol/5aol_rec.gninatypes 5aol/5aol_ligand_2.gninatypes # 0.457574 -6.79104
# 13 1 2.3188 5aol/5aol_rec.gninatypes 5aol/5aol_ligand_3.gninatypes # 0.939728 -6.57328
# 13 1 2.3188 5aol/5aol_rec.gninatypes 5aol/5aol_ligand_6.gninatypes # 0.739397 -6.3618
# 13 1 2.3188 5aol/5aol_rec.gninatypes 5aol/5aol_min.gninatypes # 0.403945 -6.75614
# 18 1 7.0000 5boj/5boj_rec.gninatypes 5boj/5boj_ligand_6.gninatypes # 1.19501 -6.9959
# 18 1 7.0000 5boj/5boj_rec.gninatypes 5boj/5boj_ligand_8.gninatypes # 0.626113 -6.95425
# 18 1 7.0000 5boj/5boj_rec.gninatypes 5boj/5boj_min.gninatypes # 0.657316 -7.06083
# 19 1 7.5129 5byi/5byi_rec.gninatypes 5byi/5byi_ligand_0.gninatypes # 0.819459 -7.82662
# 19 1 7.5129 5byi/5byi_rec.gninatypes 5byi/5byi_ligand_4.gninatypes # 1.04502 -7.68925
# 19 1 7.5129 5byi/5byi_rec.gninatypes 5byi/5byi_ligand_12.gninatypes # 1.63836 -6.88281
# 19 1 7.5129 5byi/5byi_rec.gninatypes 5byi/5byi_min.gninatypes # 0.805312 -8.03525
# 20 1 8.3188 5c2a/5c2a_rec.gninatypes 5c2a/5c2a_ligand_0.gninatypes # 1.94181 -7.60967
# 20 1 8.3188 5c2a/5c2a_rec.gninatypes 5c2a/5c2a_min.gninatypes # 1.92774 -5.68336
# 10 1 4.4634 5c3p/5c3p_rec.gninatypes 5c3p/5c3p_ligand_7.gninatypes # 1.1889 -5.45253
# 10 1 4.4634 5c3p/5c3p_rec.gninatypes 5c3p/5c3p_ligand_11.gninatypes # 1.84221 -5.29461
# 10 1 4.4634 5c3p/5c3p_rec.gninatypes 5c3p/5c3p_ligand_17.gninatypes # 1.79646 -5.12055
# 10 1 4.4634 5c3p/5c3p_rec.gninatypes 5c3p/5c3p_min.gninatypes # 0.626925 -5.17825
# 10 1 3.1273 5c5t/5c5t_rec.gninatypes 5c5t/5c5t_ligand_2.gninatypes # 1.18381 -5.6755
# 10 1 3.1273 5c5t/5c5t_rec.gninatypes 5c5t/5c5t_ligand_3.gninatypes # 1.59696 -5.65981
# 10 1 3.1273 5c5t/5c5t_rec.gninatypes 5c5t/5c5t_min.gninatypes # 1.0189 -5.27584
# 16 1 7.7696 5cbm/5cbm_rec.gninatypes 5cbm/5cbm_ligand_0.gninatypes # 1.86992 -7.01404
# 16 1 7.7696 5cbm/5cbm_rec.gninatypes 5cbm/5cbm_ligand_9.gninatypes # 1.424 -6.57131
# 16 1 7.7696 5cbm/5cbm_rec.gninatypes 5cbm/5cbm_min.gninatypes # 1.14509 -6.91905
# 19 1 5.4089 5cbs/5cbs_rec.gninatypes 5cbs/5cbs_ligand_1.gninatypes # 0.233529 -7.95474
# 19 1 5.4089 5cbs/5cbs_rec.gninatypes 5cbs/5cbs_ligand_2.gninatypes # 1.58545 -7.91324
# 19 1 5.4089 5cbs/5cbs_rec.gninatypes 5cbs/5cbs_min.gninatypes # 0.166435 -8.40554
# 10 1 3.5086 5cp9/5cp9_rec.gninatypes 5cp9/5cp9_ligand_2.gninatypes # 0.99185 -5.06438
# 10 1 3.5086 5cp9/5cp9_rec.gninatypes 5cp9/5cp9_ligand_14.gninatypes # 0.954716 -4.57422
# 10 1 3.5086 5cp9/5cp9_rec.gninatypes 5cp9/5cp9_min.gninatypes # 1.2809 -4.30599
# 16 1 2.1549 5cs3/5cs3_rec.gninatypes 5cs3/5cs3_ligand_4.gninatypes # 1.82311 -6.29699
# 14 1 2.9208 5ct2/5ct2_rec.gninatypes 5ct2/5ct2_ligand_2.gninatypes # 1.26911 -6.15821
# 14 1 2.9208 5ct2/5ct2_rec.gninatypes 5ct2/5ct2_ligand_4.gninatypes # 1.84626 -6.10543
# 14 1 2.9208 5ct2/5ct2_rec.gninatypes 5ct2/5ct2_ligand_22.gninatypes # 1.12438 -5.39554
# 17 1 4.8416 5d1r/5d1r_rec.gninatypes 5d1r/5d1r_ligand_2.gninatypes # 1.8905 -6.1728
# 17 1 4.8416 5d1r/5d1r_rec.gninatypes 5d1r/5d1r_ligand_6.gninatypes # 1.84668 -5.56118
# 17 1 4.8416 5d1r/5d1r_rec.gninatypes 5d1r/5d1r_ligand_8.gninatypes # 1.68799 -5.51773
# 18 1 8.3768 5d21/5d21_rec.gninatypes 5d21/5d21_min.gninatypes # 0.681089 -6.03151
# 20 1 4.1367 5dq8/5dq8_rec.gninatypes 5dq8/5dq8_ligand_10.gninatypes # 1.4016 -8.69993
# 20 1 4.1367 5dq8/5dq8_rec.gninatypes 5dq8/5dq8_min.gninatypes # 0.977281 -8.8455
# 17 1 3.6308 5dqe/5dqe_rec.gninatypes 5dqe/5dqe_ligand_18.gninatypes # 1.14064 -7.32507
# 17 1 3.6308 5dqe/5dqe_rec.gninatypes 5dqe/5dqe_min.gninatypes # 0.708753 -7.2295
# 20 1 10.7212 7std/7std_rec.gninatypes 7std/7std_ligand_2.gninatypes # 0.461851 -9.73453
# 20 1 10.7212 7std/7std_rec.gninatypes 7std/7std_ligand_3.gninatypes # 0.463558 -9.70523
# 20 1 10.7212 7std/7std_rec.gninatypes 7std/7std_min.gninatypes # 0.247115 -10.0621

# %%
#data_file, data_root = '/home/mtr22/cnn/gan/data/carbon.types', '/home/mtr22/cnn/gan/data/'
#data_file, data_root = '/home/mtr22/cnn/gan/data/single.types', '/home/mtr22/PDBbind/refined-set/'
data_file, data_root = '/home/mtr22/cnn/gan/data/small.types', '/home/mtr22/PDBbind/refined-set/'

data_loader = molgrid.ExampleProvider(molgrid.NullIndexTyper(),
                                      molgrid.defaultGninaLigandTyper,
                                      make_vector_types=True,
                                      data_root=data_root,
                                      shuffle=True)
data_loader.populate(data_file)

elems = ['C','C','C','C','Br','Cl','Fl','N','N','O','O','S','P','Zn','Li'] #use Li for dummy

n_types = molgrid.defaultGninaLigandTyper.num_types()
radii = np.array(list(molgrid.defaultGninaLigandTyper.get_type_radii()))

#data_file2 = '/home/mtr22/cnn/gan/data/carbon.types'
data_file2 = '/home/mtr22/cnn/gan/data/single.types'
data_loader2 = molgrid.ExampleProvider(molgrid.NullIndexTyper(),
                                      molgrid.defaultGninaLigandTyper,
                                      make_vector_types=True,
                                      data_root=data_root,
                                      shuffle=True)
data_loader2.populate(data_file2)
test_examples = data_loader2.next_batch(10)
tuple(test_examples[0].coord_sets[1].center())
# Out:
# (12.265483856201172, 36.588661193847656, 34.86753845214844)

# %%
class MolNet(nn.Module):
    '''
    Base class for a model that generates molecular structures.
    '''
    def __init__(self, n_atoms, n_types):
        super().__init__()
        
        self.n_atoms = n_atoms
        self.n_types = n_types
        
    def to(self, device):
        ret = super(MolNet, self).to(device)
        self.device = device
        return ret


class MolStruct(MolNet):
    '''
    A directly optimizable molecular structure.
    '''
    def __init__(self, n_atoms, n_types, *args):
        super().__init__(n_atoms, n_types)
        
        self.coords = nn.Parameter(torch.randn(n_atoms, 3))
        self.types = nn.Parameter(torch.randn(n_atoms, n_types+1))
        
    def forward(self, input, temp=0.0):
        
        batch_size = input.shape[0]
        
        coords = self.coords.unsqueeze(0).repeat(batch_size, 1, 1)
        types = F.softmax(self.types.unsqueeze(0).repeat(batch_size, 1, 1), dim=-1)
     
        if temp:
            coords += temp * torch.randn(batch_size, self.n_atoms, 3, device=self.device)
    
        return coords, types


class Reshape(nn.Module):
    
    def __init__(self, *shape):
        super().__init__()
        self.shape = shape
        
    def forward(self, input):
        return input.view(self.shape)


class Conv3dEncoder(nn.Module):
    
    def __init__(self, input_dims, n_output):
        super().__init__()
        
        n_input = input_dims[0]
        last_layer_size = 128 * input_dims[1]//16 \
                              * input_dims[2]//16 \
                              * input_dims[3]//16
        
        self.layers = nn.Sequential(
            nn.Conv3d(n_input, 32, kernel_size=5, padding=2),
            nn.ReLU(inplace=True), nn.MaxPool3d(2),
            nn.Conv3d(32, 64, kernel_size=5, padding=2),
            nn.ReLU(inplace=True), nn.MaxPool3d(2),
            nn.Conv3d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True), nn.MaxPool3d(2),
            nn.Conv3d(128, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True), nn.MaxPool3d(2),
            Reshape(-1, last_layer_size),
            nn.Linear(last_layer_size, n_output),
            nn.ReLU(inplace=True)
        )
    
    def forward(self, input):
        return self.layers(input)
    
    
class MolgridCNN(MolNet):
    '''
    A model that takes a molgrid as input, encodes it to a latent
    vector with a CNN, and then decodes it as a molecular structure
    using only feedforward layers.
    '''
    def __init__(self, n_atoms, n_types, dims, n_latent, var_coords=False):
        super().__init__(n_atoms, n_types)
        
        self.enc = Conv3dEncoder(dims, n_latent)
        
        self.fc_latent2 = nn.Linear(n_latent, n_latent)
        self.fc_coords = nn.Linear(n_latent, n_atoms*3)
        self.fc_types = nn.Linear(n_latent, n_atoms*(n_types+1)) # include dummy type
        
        self.var_coords = var_coords
        if var_coords:
            self.fc_coords_logstd = nn.Linear(n_latent, n_atoms*3)
    
    def forward(self, input, coords_true=None, types_true=None, temp=0.0):
        
        batch_size = input.shape[0]
        
        # get latent encoding of input density from CNN
        x = self.enc(input)
        x = self.fc_latent2(x)
        
        coords = self.fc_coords(x).view(batch_size, self.n_atoms, 3)
        types = F.softmax(self.fc_types(x).view(batch_size, self.n_atoms, -1), dim=-1)
        
        if temp:
            coords += temp * torch.randn(batch_size, self.n_atoms, 3, device=self.device)
            
        if self.var_coords:
            z = torch.randn(batch_size, self.n_atoms, 3, device=self.device)
            coords += torch.exp(self.fc_coords_logstd(x).view(batch_size, self.n_atoms, 3)) * z
        
        return coords, types
        

class MolgridRNN(MolNet):
    '''
    A model that takes a molgrid as input, encodes it to a latent
    vector with a CNN, and then decodes it as a molecular structure
    with an LSTM.
    '''
    def __init__(self, n_atoms, n_types, dims, n_latent, var_coords=False, use_att=False):
        super().__init__(n_atoms, n_types)
        
        self.enc = Conv3dEncoder(dims, n_latent)
        self.fc_latent2 = nn.Linear(n_types+4, n_latent)
        self.lstm = nn.LSTMCell(n_latent, n_latent)
        self.fc_coords = nn.Linear(n_latent, 3)
        self.fc_types = nn.Linear(n_latent, n_types+1) # include dummy type
        
        self.var_coords = var_coords
        if var_coords:
            self.fc_coords_logstd = nn.Linear(n_latent, 3)
            
        self.use_att = use_att
        if use_att:
            d_k = d_v = 10
            self.fc_Q = nn.Linear(3, d_k)
            self.fc_K = nn.Linear(3, d_k)
            self.fc_V = nn.Linear(3, d_v)
            self.att = Attention()
            self.fc_A = nn.Linear(d_v, 3)
    
    def forward(self, input, coords_true=None, types_true=None, temp=0.0):
        
        batch_size = input.shape[0]
        
        # get latent encoding of input density from CNN
        enc_output = self.enc(input)
        
        # accumulate output atoms in tensors, using batch-first dim order
        coords = torch.zeros(batch_size, 0, 3, device=self.device)
        types = torch.zeros(batch_size, 0, n_types+1, device=self.device)
        
        # initialize LSTM hidden and cell state
        lstm_h = enc_output
        lstm_c = torch.zeros(batch_size, n_latent, device=self.device)
        
        xyz = torch.zeros(batch_size, 3, device=self.device)
        t = torch.zeros(batch_size, n_types+1, device=self.device)
        
        for i in range(self.n_atoms):
            
            xyzt = torch.cat((xyz, t), dim=-1)
            lstm_i = F.relu(self.fc_latent2(xyzt))
            
            lstm_h, lstm_c = self.lstm(lstm_i, (lstm_h, lstm_c))
            
            xyz = self.fc_coords(lstm_h)
            t = F.softmax(self.fc_types(lstm_h), dim=-1)
            
            if temp:
                xyz += temp * torch.randn(1, batch_size, 3, device=self.device)
            
            if self.var_coords:
                z = torch.randn(1, batch_size, 3, device=self.device)
                xyz += torch.exp(self.fc_coords_logstd(lstm_h)) * z
            
            coords = torch.cat((coords, xyz.unsqueeze(1)), dim=1)
            types = torch.cat((types, t.unsqueeze(1)), dim=1)
            
            if self.use_att:
                Q = F.relu(self.fc_Q(xyz.unsqueeze(1)))
                K = F.relu(self.fc_K(coords))
                V = F.relu(self.fc_V(coords))
                A = self.att(Q, K, V)
                xyz = F.relu(self.fc_A(A)).view(batch_size, 3)
            
            if coords_true is not None: # teacher forcing
                xyz = coords_true[:,i,:]
                t = types_true[:,i,:]
        
        return coords, types
    

class MolgridRNN2(MolNet):
    '''
    A model that takes a molgrid as input, encodes it to a latent
    vector with a CNN, and then decodes it as a molecular structure
    with an LSTM.
    '''
    def __init__(self, n_atoms, n_types, dims, n_latent, var_coords=False, n_lstm=1,
                 c2grid=None, batch_radii=None):
        super().__init__(n_atoms, n_types)
        
        self.enc = Conv3dEncoder(dims, n_latent)
        self.n_lstm = n_lstm
        self.lstm = nn.LSTM(n_latent, n_latent, n_lstm)
        self.fc_coords = nn.Linear(n_latent, 3)
        self.fc_types = nn.Linear(n_latent, n_types+1) # include dummy type
        
        self.var_coords = var_coords
        if var_coords:
            self.fc_coords_logstd = nn.Linear(n_latent, 3)
        
        self.c2grid = c2grid
        self.batch_radii = batch_radii
    
    def forward(self, input, coords_true=None, types_true=None, temp=0.0):
        
        batch_size = input.shape[0]
                
        # accumulate output atoms in tensors, using batch-first dim order
        coords = torch.zeros(batch_size, 0, 3, device=self.device)
        types = torch.zeros(batch_size, 0, n_types+1, device=self.device)
        
        # initialize LSTM hidden and cell state
        lstm_h = torch.zeros(self.n_lstm, batch_size, n_latent, device=self.device)
        lstm_c = torch.zeros(self.n_lstm, batch_size, n_latent, device=self.device)
        
        for i in range(self.n_atoms):
            
            # get latent encoding of input density from CNN
            lstm_i = self.enc(input).unsqueeze(0)
            
            _, (lstm_h, lstm_c) = self.lstm(lstm_i, (lstm_h, lstm_c))
                        
            xyz = self.fc_coords(lstm_h[-1:]).permute(1, 0, 2)
            t = F.softmax(self.fc_types(lstm_h[-1:]), dim=-1).permute(1, 0, 2)
            
            if temp:
                xyz = xyz + temp * torch.randn(batch_size, 1, 3, device=self.device)
            
            if self.var_coords:
                xyz_std = torch.exp(self.fc_coords(lstm_h[-1:])).permute(1, 0, 2)
                xyz = xyz + xyz_std * torch.randn(batch_size, 1, 3, device=self.device)
            
            coords = torch.cat((coords, xyz), dim=1)
            types = torch.cat((types, t), dim=1)
            
            if i+1 < self.n_atoms:
                atom_grid = self.c2grid(xyz, t[:,:,:-1].clone(), self.batch_radii)
                input = input - atom_grid
        
        return coords, types


class MolgridAttn(MolNet):
    '''
    A model that takes a molgrid as input, encodes it to a latent
    vector with a CNN, and then decodes it as a molecular structure
    using attention.
    '''
    def __init__(self, n_atoms, n_types, dims, n_latent, var_coords=False):
        super().__init__(n_atoms, n_types)
        
        self.enc = Conv3dEncoder(dims, n_latent)
        
        self.att = Attention()
        d_k = d_v = n_latent//4
        
        self.fc_Q_oo = nn.Linear(n_types+4, d_k)
        self.fc_K_oo = nn.Linear(n_types+4, d_k)
        self.fc_V_oo = nn.Linear(n_types+4, d_v)
        
        self.fc_Q_io = nn.Linear(d_k, d_k)
        self.fc_K_io = nn.Linear(n_latent, d_k)
        self.fc_V_io = nn.Linear(n_latent, d_v)
        
        self.fc_coords = nn.Linear(d_k, 3)
        self.fc_types = nn.Linear(d_k, n_types+1) # include dummy type
        
        self.var_coords = var_coords
        if var_coords:
            self.fc_coords_logstd = nn.Linear(d_k, 3)
    
    def forward(self, input, temp=0.0):
        
        batch_size = input.shape[0]
        
        # get latent encoding of input density from CNN
        x = self.enc(input).unsqueeze(1)
        
        # accumulate output atoms in tensors
        coords = torch.zeros(batch_size, self.n_atoms, 3, device=self.device)
        types = torch.zeros(batch_size, self.n_atoms, n_types+1, device=self.device)
        
        xyz = torch.zeros(batch_size, 1, 3, device=self.device)
        t = torch.zeros(batch_size, 1, self.n_types+1, device=self.device)
        #t[:,:,-1] = 1
    
        xyzt = torch.cat((xyz, t), dim=-1) # (batch_size, 1, n_types+4)
        ct = torch.cat((coords, types), dim=-1) # (batch_size, n_atoms, n_types+4)
        
        for i in range(self.n_atoms):
            
            Q_oo = self.fc_Q_oo(xyzt) # (batch_size, 1, d_k)
            K_oo = self.fc_K_oo(ct) # (batch_size, n_atoms, d_k)
            V_oo = self.fc_V_oo(ct) # (batch_size, n_atoms, d_v)
            a_oo = self.att(Q_oo, K_oo, V_oo) # (batch_size, 1, d_v) TODO mask
                     
            Q_io = self.fc_Q_io(a_oo) # (batch_size, 1, d_k)
            K_io = self.fc_K_io(x) # (batch_size, n_atoms, d_k)
            V_io = self.fc_V_io(x) # (batch_size, n_atoms, d_k)
            a_io = self.att(Q_io, K_io, V_io)  # (batch_size, 1, d_k)
            
            xyz = self.fc_coords(a_io)
            t = F.softmax(self.fc_types(a_io), dim=-1)

            if temp:
                xyz += temp * torch.randn(1, batch_size, 3, device=self.device)
            
            if self.var_coords:
                z = torch.randn(1, batch_size, 3, device=self.device)
                xyz += torch.exp(self.fc_coords_logstd(a_io).view(1, batch_size, 3)) * z
            
            coords = torch.cat((coords[:,:i,:], xyz, coords[:,i+1:,:]), dim=1)
            types = torch.cat((types[:,:i,:], t, types[:,i+1:,:]), dim=1)
            
            xyzt = torch.cat((xyz, t), dim=-1)
            ct = torch.cat((coords, types), dim=-1)
        
        return coords, types


class Attention(nn.Module):
    
    def forward(self, Q, K, V):
        d_k = K.shape[2]
        QKT = torch.bmm(Q, K.transpose(1, 2))
        return torch.bmm(F.softmax(QKT / np.sqrt(d_k), dim=2), V)


def weight_init(m):
    if isinstance(m, nn.Conv3d) or isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight.data)
    elif isinstance(m, nn.LSTM):
        for p in m.parameters():
            nn.init.uniform_(p.data)

# %%
def write_xyz_and_arrows(types, coords, dcoords, out, out2, sample=False, state=0, scale=1):
    '''
    From BxNxT array of types, BxNx3 array of coords, and BxNx3 gradient,
    generate a multi model xyz file (plus gradient) and a pymol script of
    gradient arrows. Optionally sample atom type vector instead of max.
    '''
    i = 0
    for ts, xyzs, dxyzs in zip(types, coords, dcoords):
        out.write('{:d}\n\n'.format(len(ts)))
        
        j = 0
        for t, (x,y,z), (dx,dy,dz) in zip(ts, xyzs, dxyzs):
        
            if sample:
                elem = np.random.choice(elems, p=t)
            else:
                elem = elems[np.argmax(t)]

            out.write('{:s}   {:f}  {:f}  {:f}  {:f}  {:f}  {:f}\n'.format(elem,x,y,z,dx,dy,dz))
            
            x2 = x + scale*dx
            y2 = y + scale*dy
            z2 = z + scale*dz
            out2.write('cgo_arrow [{}, {}, {}], [{}, {}, {}]'.format(x,y,z,x2,y2,z2) + 
                       ', name=arrow_{}_{}, state={}, color=black'.format(i, j, state) +
                       ', radius=0.05, hradius=0.1, hlength=0.25\n')
            j += 1
        i += 1
        
def example_vec_to_tensors(examples, max_n_atoms, device):
    
    batch_size = len(examples)
    n_types = len(examples[0].coord_sets[1].type_vector[0])
    
    # fill tensors with coords, types, and raddi
    coords = torch.zeros(batch_size, max_n_atoms, 3, device=device)
    types = torch.zeros(batch_size, max_n_atoms, n_types+1, device=device)
    radii = torch.zeros(batch_size, max_n_atoms, device=device)
    
    for i, x in enumerate(examples):
        lig = x.coord_sets[1]
        n_atoms = lig.size()
        xyz = torch.tensor(lig.coords)
        t = torch.tensor(lig.type_vector)
        r = torch.tensor(lig.radii)[torch.argmax(t, dim=-1)]
        coords[i,:n_atoms,:] = xyz
        types[i,:n_atoms,:-1] = t
        radii[i,:n_atoms] = r
        types[i,n_atoms:,-1] = 1.0 # dummy type
        
    return coords, types, radii
    
def out_of_box_loss(c, max_val):
    '''hingey loss at box boundaries'''
    return (F.relu(abs(c)-max_val)).sum()

def grad_norm(model):
    total_norm = 0
    for p in model.parameters():
        if p.grad is not None:
            param_norm = p.grad.data.norm(2)
            total_norm += param_norm.item() ** 2
    total_norm = total_norm ** (1/2)
    return total_norm

def get_ylim(vals):
    min_val = 0 #min(vals)
    max_val = max(vals)
    val_range = max_val - min_val
    return min_val - 0.1*val_range, max_val + 0.1*val_range

x_min, x_max = np.array([-15, 15])
y_min, y_max = np.array([-1, 4])
max_val = 23.5/2
x = torch.arange(x_min, x_max, 0.01)
y = torch.tensor([out_of_box_loss(x_, max_val) for x_ in x])
plt.figure()
plt.ylabel('out-of-box loss')
plt.xlabel('position')
plt.hlines(0, x_min, x_max, 'k', lw=1)
plt.vlines(0, y_min, y_max, 'k', lw=1)
plt.vlines([-max_val, max_val], y_min, y_max, 'r', 'dashed', lw=1)
plt.plot(x, y, 'b', lw=2)
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
# Out:
# (-1, 4)

# %%
device = 'cuda'
model_type = 'rnn'
batch_size = 10
n_atoms = 50
n_latent = 1024
temp = 0.0
rotate = True
var_coords = False
type_ent = False
do_plot = True

batch_radii = torch.tensor(np.tile(radii, (batch_size, 1)), dtype=torch.float32, device=device)

gmaker = molgrid.GridMaker(resolution=0.5,
                           dimension=23.5,
                           radius_scale=1,
                           radius_type_indexed=True)

dims = gmaker.grid_dimensions(n_types)
grid_size = dims[0] * dims[1] * dims[2] * dims[3]
c2grid = molgrid.Coords2Grid(gmaker, center=(0,0,0))

if model_type == 'cnn':
    model = MolgridCNN(n_atoms, n_types, dims, n_latent, var_coords).to(device)
elif model_type == 'rnn':
    model = MolgridRNN(n_atoms, n_types, dims, n_latent, var_coords, use_att=True).to(device)
elif model_type == 'rnn2':
    model = MolgridRNN2(n_atoms, n_types, dims, n_latent, var_coords, c2grid, batch_radii).to(device)
else:
    raise ValueError('unknown model type {}'.format(model_type))

model.apply(weight_init)

optimizer = optim.Adam(model.parameters(), lr=1e-4)
lr_policy = optim.lr_scheduler.StepLR(optimizer, 1, gamma=0.5)

losses = []
grid_losses = []
oob_losses = []
type_losses = []
dummy_losses = []
type_entropies = []
grad_norms = []
lrs = []

loss_out = open('loss.txt', 'wt')
pred_out = open('pred.xyz', 'wt')
arrows_out = open('pred_arrows.pymol', 'wt')

n_iterations = 50000
step_interval = 10000
print_interval = 1

grid_true = torch.empty(batch_size, *dims, dtype=torch.float32, device=device)
grid_test = torch.empty(batch_size, *dims, dtype=torch.float32, device=device)

coords_test, typesd_test, _ = example_vec_to_tensors(test_examples, n_atoms, device=device)
types_test = typesd_test[:,:,:-1].clone()
dummy_test = typesd_test[:,:,-1].clone()
type_count_test = types_test.sum(dim=1)
gmaker.forward(test_examples, grid_test, random_rotation=False)

fig, ax = plt.subplots(1, 3, sharex=True, squeeze=True, figsize=(16, 5), gridspec_kw=dict(wspace=0.25))
ax[0].plot(grid_losses, label='grid loss')
ax[0].plot(oob_losses, label='oob loss')
ax[0].plot(type_losses, label='type loss')
ax[0].plot(type_losses, label='dummy loss')
ax[0].plot(type_entropies, label='type entropy')
ax[0].legend(loc=0)
ax[0].set_xlabel('iteration')
ax[1].plot(grad_norms, label='gradient norm')
ax[1].legend(loc=0)
ax[1].set_xlabel('iteration')
ax[2].plot(lrs, label='learning rate')
ax[2].legend(loc=0)
ax[2].set_xlabel('iteration')

i = 0
while i < n_iterations:
    try:
        optimizer.zero_grad()
        
        # get next batch of examples and compute true density
        examples = data_loader.next_batch(batch_size)
        coords_true, typesd_true, _ = example_vec_to_tensors(examples, n_atoms, device=device)
        types_true = typesd_true[:,:,:-1].clone()
        dummy_true = typesd_true[:,:,-1].clone()
        type_count_true = types_true.sum(dim=1)
        gmaker.forward(examples, grid_true, random_rotation=rotate)
        
        # generate coords, types, and density from model
        coords_gen, typesd_gen = model(grid_true, coords_true, typesd_true, temp=temp)
        types_gen = typesd_gen[:,:,:-1].clone()
        dummy_gen = typesd_gen[:,:,-1].clone()
        type_count_gen = types_gen.sum(dim=1)
        grid_gen = c2grid(coords_gen, types_gen, batch_radii)
        
        # compute loss
        grid_loss = F.mse_loss(grid_true, grid_gen)
        oob_loss  = out_of_box_loss(coords_gen, max_val=11.5)
        type_loss = F.mse_loss(type_count_true, type_count_gen)
        dummy_loss = F.mse_loss(dummy_true, dummy_gen)
        type_entropy = -torch.sum(typesd_gen * torch.log(typesd_gen)) / (batch_size * n_atoms)
        
        if i == 0: # normalize losses by initial value
            k_grid_loss    = 1/float(grid_loss)
            k_oob_loss     = 1e-2 # avoid divide by zero
            k_type_loss    = 1/float(type_loss)
            k_dummy_loss   = 1/float(dummy_loss)
            k_type_entropy = 0
        
        grid_loss    *= k_grid_loss
        oob_loss     *= k_oob_loss
        type_loss    *= k_type_loss
        dummy_loss   *= k_dummy_loss
        type_entropy *= k_type_entropy
        
        loss = grid_loss + oob_loss + type_loss + dummy_loss + type_entropy
        
        # backpropagate and clip gradient
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), 100)
        
        # record metrics
        losses.append(float(loss))
        grid_losses.append(float(grid_loss))
        oob_losses.append(float(oob_loss))
        type_losses.append(float(type_loss))
        dummy_losses.append(float(dummy_loss))
        type_entropies.append(float(type_entropy))
        grad_norms.append(float(grad_norm(model)))
        lrs.append(float(optimizer.param_groups[0]['lr']))
        
        row = (i, losses[-1], grid_losses[-1], oob_losses[-1], type_losses[-1], \
               dummy_losses[-1], type_entropies[-1], grad_norms[-1])
        loss_out.write('%i %f %f %f %f %f %f %f\n' % row)
        loss_out.flush()
        
        # check gradient
        if np.isnan(grad_norms[-1]) or np.isinf(grad_norms[-1]):
            print('gradient norm is {}'.format(grad_norms[-1]))
            break
        
        # update weights
        optimizer.step()
        i += 1

        if i % print_interval == 0: # plot and evaluate test density

            if do_plot: # dynamic plotting
                ax[0].get_lines()[0].set_data(range(i), grid_losses)
                ax[0].get_lines()[1].set_data(range(i), oob_losses)
                ax[0].get_lines()[2].set_data(range(i), type_losses)
                ax[0].get_lines()[3].set_data(range(i), dummy_losses)
                ax[0].get_lines()[3].set_data(range(i), type_entropies)
                ax[0].set_xlim(0, i)
                ax[0].set_ylim(get_ylim(grid_losses+oob_losses+type_losses+dummy_losses+type_entropies))
                ax[1].get_lines()[0].set_data(range(i), grad_norms)
                ax[1].set_xlim(0, i)
                ax[1].set_ylim(get_ylim(grad_norms))
                ax[2].get_lines()[0].set_data(range(i), lrs)
                ax[2].set_xlim(0, i)
                ax[2].set_ylim(get_ylim(lrs))
                display.display(fig)
                display.clear_output(wait=True)
            
            # write out predicted structure and gradient 
            optimizer.zero_grad()
            
            # generate coords, types, and density from model
            coords_gen, typesd_gen = model(grid_test, coords_test, typesd_test, temp=temp)
            coords_gen.retain_grad()
            types_gen = typesd_gen[:,:,:-1].clone()
            dummy_gen = typesd_gen[:,:,-1].clone()
            type_count_gen = types_gen.sum(dim=1)
            grid_gen = c2grid(coords_gen, types_gen, batch_radii)
            
            # compute loss
            grid_loss = F.mse_loss(grid_test, grid_gen)
            oob_loss  = out_of_box_loss(coords_gen, max_val=11.5)
            type_loss = F.mse_loss(type_count_test, type_count_gen)
            dummy_loss = F.mse_loss(dummy_test, dummy_gen)
            type_entropy = -torch.sum(typesd_gen * torch.log(typesd_gen)) / (batch_size * n_atoms)
            
            grid_loss    *= k_grid_loss
            oob_loss     *= k_oob_loss
            type_loss    *= k_type_loss
            dummy_loss   *= k_dummy_loss
            type_entropy *= k_type_entropy
            
            loss = grid_loss + oob_loss + type_loss + dummy_loss + type_entropy
            
            # backpropagate and clip gradient
            loss.backward()
            nn.utils.clip_grad_norm_(model.parameters(), 100)

            # write out generated structure and gradient
            write_xyz_and_arrows(
                typesd_gen.detach().cpu().numpy()[:1,:,:],
                coords_gen.detach().cpu().numpy()[:1,:,:],
                coords_gen.grad.detach().cpu().numpy()[:1,:,:],
                pred_out, arrows_out, sample=True,
                state=i//print_interval,
                scale=-5000)
            pred_out.flush()
            arrows_out.flush()

            # check for convergence
            if i > 2 and abs(losses[-1] - losses[-2])/abs(losses[-2]) < 1e-6: 
                print('converged')
                break
        
        if i % step_interval == 0:
            lr_policy.step()
    
    except KeyboardInterrupt:
        print('interrupted')
        break

print(model_type, os.path.basename(data_file).split()[0], rotate, var_coords, type_ent)
# Out:
# rnn small.types True False False

# %%
print(k_grid_loss, k_oob_loss, k_type_loss, k_type_entropy)

# %%
elems
