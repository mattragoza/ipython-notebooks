# %% [markdown]
# Atom Gradient Visualization

# %%
import py3Dmol

def split_xyz(xyz, threshold):
    count1, count2 = 0, 0
    atoms1, atoms2 = [], []
    for i, line in enumerate(xyz.split('\n')):
        if i < 2: continue
        data = line.split()
        if float(data[-1])**2 + float(data[-2])**2 + float(data[-3])**2 <= threshold**2:
            count1 += 1
            atoms1.append(line)
        else:
            count2 += 1
            atoms2.append(line)
    xyz1 = '\n'.join([str(count1), ''] + atoms1)
    xyz2 = '\n'.join([str(count2), ''] + atoms2)
    return xyz1, xyz2

def view_gradient_animation(view, rec_fname, lig_fname,
                     rec_style={'stick': {'radius': 0.1}},
                     lig_style={'stick': {'colorscheme': 'greenCarbon'}},
                     threshold=1.0,
                     loop='forward'):
    with open(rec_fname, 'r') as f:
        rec_xyz = f.read()
    with open(lig_fname, 'r') as f:
        lig_xyz = f.read()
    
    view.clear()
    #view.setBackgroundColor(0)
    
    view.addModel(lig_xyz, 'xyz')
    view.setClickable({}, True)
    view.addModel(rec_xyz, 'xyz')

    view.setStyle({}, rec_style)
    view.setStyle({'clickable': True}, lig_style)
    
    view.render()

    view.vibrate(10, 1)
    view.animate({'loop': loop})
    view.zoomTo()
    return view

# %%
view = py3Dmol.view(width=900, height=600)

# %%
view_gradient_animation(view, 'xyz/csar_set1_100_rec.xyz', 'xyz/csar_set1_100_lig.xyz').show()
# Out:
# <div id="3dmolviewer_14855471530040712"  style="position: relative; width: 900px; height: 600px">
# <script>
# if(typeof $3Dmolpromise === 'undefined') $3Dmolpromise = $.when($.getScript('http://3dmol.csb.pitt.edu/build/3Dmol.js'))
# $3Dmolpromise.done(function() {
# var viewer = $3Dmol.createViewer($("#3dmolviewer_14855471530040712"),{backgroundColor:"white"});
# 	viewer.clear();
# 	viewer.addModel("11\n\nN 18.196 22.015 31.468 -0.67857 0.39189 -0.83875\nC 17.045 22.311 32.35 0.85142 -0.05183 0.11318\nC 16.376 23.653 31.94 0.82501 0.14856 0.35036\nC 17.471 22.28 33.838 0.95859 0.026904 0.11146\nO 16.318 22.272 34.669 -0.27299 -0.228 0.047679\nC 18.235 20.994 34.175 0.1752 0.32682 0.056405\nC 20.445 20.961 30.983 -0.0774 -0.15385 0.20678\nN 19.338 20.747 33.229 0.55476 -0.58463 0.45747\nC 19.285 21.247 31.92 -0.029942 0.027641 0.20836\nO 16.588 24.077 30.781 -0.55826 0.46936 -0.26742\nO 15.655 24.22 32.783 -0.94497 0.29758 -0.08492","xyz");
# 	viewer.setClickable({},true);
