# %%
# %matplotlib inline
import sys, os, glob, parse
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

ligan_dir = '/home/mtr22/dvorak/net/pulsar/home/koes/mtr22/gan'
sys.path.append(ligan_dir)

from results import aggregate_data, plot_lines, plot_strips

work_dir = os.path.join(ligan_dir, 'test_atom_fitting')
os.chdir(work_dir)
os.getcwd()
# Out:
# Warning: ignoring the following <class 'ImportError'>: libhdf5_cpp.so.103: cannot open shared object file: No such file or directory
# '/home/mtr22/dvorak/net/pulsar/home/koes/mtr22/gan/test_atom_fitting'

# %%
metric_files = glob.glob('asdf/*.gen_metrics')
metric_files
# Out:
# ['asdf/n_095_1_1_100.gen_metrics',
#  'asdf/n_095_1_1_20.gen_metrics',
#  'asdf/n_095_1_1_50.gen_metrics',
#  'asdf/n_095_1_5_50.gen_metrics',
#  'asdf/n_095_1_0_100.gen_metrics',
#  'asdf/n_095_1_2_100.gen_metrics',
#  'asdf/n_095_1_5_100.gen_metrics',
#  'asdf/n_100_1_10_100.gen_metrics',
#  'asdf/n_095_1_1_10.gen_metrics',
#  'asdf/n_095_1_10_100.gen_metrics',
#  'asdf/n_090_1_10_100.gen_metrics',
#  'asdf/n_085_1_10_100.gen_metrics',
#  'asdf/n_100_1_1_100.gen_metrics',
#  'asdf/n_100_1_100_100.gen_metrics',
#  'asdf/n_100_1_10_10.gen_metrics',
#  'asdf/n_100_1_10_1000.gen_metrics',
#  'asdf/n_100_2_10_100.gen_metrics',
#  'asdf/n_100_3_10_100.gen_metrics',
#  'asdf/n_100_4_10_100.gen_metrics',
#  'asdf/n_100_5_10_100.gen_metrics']

# %%
name_format = 'n_{r_factor:d}_{beam_size:d}_{interm_iters:d}_{final_iters:d}'

remove_cols = ['lig_norm', 'lig_gen_norm', 'lig_gen_loss', 'lig_var', 'lig_gen_var',
               'lig_fit_radius', 'lig_gen_fit_radius']

fit_dfs = []
for metric_file in metric_files:
    fit_df = pd.read_csv(metric_file, sep=' ')
    for c in remove_cols:
        del fit_df[c]
    fit_name = os.path.splitext(os.path.basename(metric_file))[0]
    fit_df['fit_name'] = fit_name
    fit_params = parse.parse(name_format, fit_name).named
    for param, value in fit_params.items():
        fit_df[param] = value
    fit_df['r_factor'] /= 100.
    fit_dfs.append(fit_df)

df = pd.concat(fit_dfs)

group_cols = ['fit_name', 'lig_name']
agg_df = aggregate_data(df, group_cols, sample_idx=pd.Series.nunique)
agg_df
# Out:
#                           sample_idx  lig_fit_loss  lig_gen_fit_loss  \
# fit_name        lig_name
# n_085_1_10_100  1ajv_min          25      0.013013         48.993925
# n_090_1_10_100  1ajv_min          25      0.013013         46.358464
# n_095_1_0_100   1ajv_min          25      6.993844         36.085734
# n_095_1_10_100  1ajv_min          25      0.013013         43.097409
# n_095_1_1_10    1ajv_min          25      3.918014         38.646560
# n_095_1_1_100   1ajv_min          25      1.248957         36.071931
# n_100_1_100_100 1ajv_min         20.563675                   6.20
# n_100_1_10_10   1ajv_min          2.620773                   4.88
# n_100_1_10_100  1ajv_min          3.128270                   4.88
# n_100_1_10_1000 1ajv_min          8.272842                   4.88
# n_100_1_1_100   1ajv_min          1.313673                   4.40
# n_100_2_10_100  1ajv_min          9.502754                   4.52
# n_100_3_10_100  1ajv_min         20.166167                   4.16
# n_100_4_10_100  1ajv_min         35.289153                   3.92
# n_100_5_10_100  1ajv_min         54.991115                   3.72
#
#                           lig_gen_fit_RMSD  r_factor  beam_size  interm_iters  \
# fit_name        lig_name
# n_085_1_10_100  1ajv_min               NaN      0.85          1            10
# n_090_1_10_100  1ajv_min               NaN      0.90          1            10
# n_095_1_0_100   1ajv_min               NaN      0.95          1             0
# n_095_1_10_100  1ajv_min          0.444683      0.95          1            10
# n_095_1_1_10    1ajv_min          0.504925      0.95          1             1
# n_095_1_1_100   1ajv_min          0.474578      0.95          1             1
# n_095_1_1_20    1ajv_min          0.467123      0.95          1             1
# n_095_1_1_50    1ajv_min          0.462159      0.95          1             1
# n_095_1_2_100   1ajv_min               NaN      0.95          1             2
# n_095_1_5_100   1ajv_min          0.464039      0.95          1             5
# n_095_1_5_50    1ajv_min          0.442677      0.95          1             5
# n_100_1_100_100 1ajv_min               NaN      1.00          1           100
# n_100_1_10_10   1ajv_min               NaN      1.00          1            10
# n_100_1_10_100  1ajv_min               NaN      1.00          1            10
# n_100_1_10_1000 1ajv_min               NaN      1.00          1            10
# n_100_1_1_100   1ajv_min               NaN      1.00          1             1
# n_100_2_10_100  1ajv_min               NaN      1.00          2            10
# n_100_3_10_100  1ajv_min               NaN      1.00          3            10
# n_100_4_10_100  1ajv_min               NaN      1.00          4            10
# n_100_5_10_100  1ajv_min               NaN      1.00          5            10
#
#                           final_iters
# fit_name        lig_name
# n_085_1_10_100  1ajv_min          100
# n_090_1_10_100  1ajv_min          100
# n_095_1_0_100   1ajv_min          100
# n_095_1_10_100  1ajv_min          100
# n_095_1_1_10    1ajv_min           10
# n_095_1_1_100   1ajv_min          100
# n_095_1_1_20    1ajv_min           20
# n_095_1_1_50    1ajv_min           50
# n_095_1_2_100   1ajv_min          100
# n_095_1_5_100   1ajv_min          100
# n_095_1_5_50    1ajv_min           50
# n_100_1_100_100 1ajv_min          100
# n_100_1_10_10   1ajv_min           10
# n_100_1_10_100  1ajv_min          100
# n_100_1_10_1000 1ajv_min         1000
# n_100_1_1_100   1ajv_min          100
# n_100_2_10_100  1ajv_min          100
# n_100_3_10_100  1ajv_min          100
# n_100_4_10_100  1ajv_min          100
# n_100_5_10_100  1ajv_min          100

# %%
metrics = [
    'lig_fit_n_atoms',       'lig_gen_fit_n_atoms',
    'lig_fit_time',          'lig_gen_fit_time',
    'lig_fit_loss',          'lig_gen_fit_loss',
    'lig_gen_fit_type_diff', 'lig_gen_fit_RMSD'
]
sns.set_context('notebook')
sns.set_style('white')

# %% [markdown]
# # Round 1
# ```python
# r_factor     = 1.00 [0.85, 0.90, 0.95, 1.00]
# beam_size    = 1    [1, 2, 3, 4, 5]
# interm_iters = 10   [1, 10, 100]
# final_iters  = 100  [10, 100, 1000]
# ```

# %%
# ROUND 1 r_factor
fit_names = ['n_100_1_10_100', 'n_095_1_10_100', 'n_090_1_10_100', 'n_085_1_10_100']
plot_df = df[df['fit_name'].isin(fit_names)]
fig = plot_strips('r_factor.png', plot_df, x='r_factor', y=metrics,
                  n_cols=2, height=4, width=4, point=True,
                  share_ylim_pat=r'^lig_(gen_)?')
plt.show()

# %%
plot_df[plot_df['lig_gen_fit_type_diff'] == 0]
# Out:
#     lig_name  sample_idx  lig_fit_loss  lig_gen_fit_loss  lig_fit_n_atoms  \
# 9   1ajv_min           9      0.000277         45.256222             41.0
# 18  1ajv_min          18      0.069989         35.934105             41.0
#
#     lig_gen_fit_n_atoms  lig_fit_time  lig_gen_fit_time  \
# 9                  41.0      3.459878          3.175146
# 18                 41.0      3.467525          3.171704
#
#     lig_gen_fit_type_diff  lig_gen_fit_RMSD        fit_name  r_factor  \
# 9                     0.0          0.452168  n_095_1_10_100      0.95
# 18                    0.0          0.437199  n_095_1_10_100      0.95
#
#     beam_size  interm_iters  final_iters
# 9           1            10          100
# 18          1            10          100

# %%
# ROUND 1 interm_iters
fit_names = ['n_100_1_1_100', 'n_100_1_10_100', 'n_100_1_100_100']
plot_df = df[df['fit_name'].isin(fit_names)]
fig = plot_strips('interm_iters.png', plot_df, x='interm_iters', y=metrics,
                  n_cols=2, height=4, width=4, point=True,
                  share_ylim_pat=r'^lig_(gen_)?')
plt.show()

# %%
# ROUND 1 final_iters
fit_names = ['n_100_1_10_10', 'n_100_1_10_100', 'n_100_1_10_1000']
plot_df = df[df['fit_name'].isin(fit_names)]
fig = plot_strips('final_iters.png', plot_df, x='final_iters', y=metrics,
                  n_cols=2, height=4, width=4, point=True,
                  share_ylim_pat=r'^lig_(gen_)?')
plt.show()

# %%
# ROUND 1 beam_size
fit_names = ['n_100_1_10_100', 'n_100_2_10_100', 'n_100_3_10_100',
             'n_100_4_10_100', 'n_100_5_10_100']
plot_df = df[df['fit_name'].isin(fit_names)]
fig = plot_strips('beam_size.png', plot_df, x='beam_size', y=metrics,
                  n_cols=2, height=4, width=4, point=True,
                  share_ylim_pat=r'^lig_(gen_)?')
plt.show()

# %%
# ROUND 1 improvement
agg_df.loc['n_095_1_1_100'] - agg_df.loc['n_100_1_10_100']
# Out:
#           sample_idx  lig_fit_loss  lig_gen_fit_loss  lig_fit_n_atoms  \
# lig_name
# 1ajv_min           0      1.235944         -3.952931            -0.08
#
#           lig_gen_fit_n_atoms  lig_fit_time  lig_gen_fit_time  \
# lig_name
# 1ajv_min                 4.64     -2.076919         -1.812383
#
#           lig_gen_fit_type_diff  lig_gen_fit_RMSD  r_factor  beam_size  \
# lig_name
# 1ajv_min                  -2.16               NaN     -0.05          0
#
#           interm_iters  final_iters
# lig_name
# 1ajv_min            -9            0

# %% [markdown]
# # Round 2
# ```python
# r_factor     = 0.95 [0.95]
# beam_size    = 1    [1]
# interm_iters = 1    [0, 1, 2, 5, 10]
# final_iters  = 100  [10, 20, 50, 100]
# ```

# %%
# ROUND 2 interm_iters
fit_names = ['n_095_1_0_100', 'n_095_1_1_100', 'n_095_1_2_100',
             'n_095_1_5_100', 'n_095_1_10_100']
plot_df = df[df['fit_name'].isin(fit_names)]
fig = plot_strips('interm_iters2.png', plot_df, x='interm_iters', y=metrics,
                  n_cols=2, height=4, width=4, point=True,
                  share_ylim_pat=r'^lig_(gen_)?')
plt.show()

# %%
plot_df[plot_df['lig_gen_fit_type_diff'] == 0]
# Out:
#     lig_name  sample_idx  lig_fit_loss  lig_gen_fit_loss  lig_fit_n_atoms  \
# 7   1ajv_min           7      0.002579         38.297096             41.0
# 9   1ajv_min           9      0.013290         45.255817             41.0
# 9   1ajv_min           9      0.000277         45.256222             41.0
# 18  1ajv_min          18      0.069989         35.934105             41.0
#
#     lig_gen_fit_n_atoms  lig_fit_time  lig_gen_fit_time  \
# 7                  41.0      1.405031          1.324560
# 9                  41.0      2.327403          2.141870
# 9                  41.0      3.459878          3.175146
# 18                 41.0      3.467525          3.171704
#
#     lig_gen_fit_type_diff  lig_gen_fit_RMSD        fit_name  r_factor  \
# 7                     0.0          0.474578   n_095_1_1_100      0.95
# 9                     0.0          0.464039   n_095_1_5_100      0.95
# 9                     0.0          0.452168  n_095_1_10_100      0.95
# 18                    0.0          0.437199  n_095_1_10_100      0.95
#
#     beam_size  interm_iters  final_iters
# 7           1             1          100
# 9           1             5          100
# 9           1            10          100
# 18          1            10          100

# %%
# ROUND 2 final_iters
fit_names = ['n_095_1_1_10', 'n_095_1_1_20', 'n_095_1_1_50', 'n_095_1_1_100']
plot_df = df[df['fit_name'].isin(fit_names)]
fig = plot_strips('final_iters2.png', plot_df, x='final_iters', y=metrics,
                  n_cols=2, height=4, width=4, point=True,
                  share_ylim_pat=r'^lig_(gen_)?')
plt.show()

# %% [markdown]
# # Final
# ```python
# r_factor     = 0.95
# beam_size    = 1
# interm_iters = 5
# final_iters  = 50
# ```

# %%
# PARAM SEARCH RESULTS
fit_names = ['n_100_1_10_100', 'n_095_1_1_100', 'n_095_1_5_50']
plot_df = df[df['fit_name'].isin(fit_names)]
plot_df['round'] = plot_df['fit_name'].apply(fit_names.index)
fig = plot_strips('param_search.png', plot_df, x='round', y=metrics,
                  n_cols=2, height=4, width=4, point=True,
                  share_ylim_pat=r'^lig_(gen_)?')
plt.show()
# Out:
# /home/mtr22/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
